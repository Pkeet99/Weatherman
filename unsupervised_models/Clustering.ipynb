# %% [markdown]
# ### Clustering to reduce features

# %%
import os
import pandas as pd
from datetime import datetime, timedelta
from sklearn.neighbors import KNeighborsClassifier
from sklearn.cluster import KMeans
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from tqdm import tqdm
from sklearn.metrics.cluster import silhouette_score

# %%
ROOT_DIR = os.path.realpath(os.path.join(os.getcwd(), '..'))
cln_pkl_loc = os.path.join(ROOT_DIR, 'data','cleanweathersmall.pkl')

# %%
df = pd.read_pickle(cln_pkl_loc)
df.groupby('station').count()
# Out:
#          time  temp  dwpt  rhum  prcp  wdir  wspd  pres
# station
# 0CNUO    8784  8784  8784  8784  8784  8784  8784  8784
# 0CO7B    8784  8784  8784  8784  8784  8784  8784  8784
# 0FV1F    8784  8784  8784  8784  8784  8784  8784  8784
# 1J1PJ    8784  8784  8784  8784  8784  8784  8784  8784
# 1JWST    8784  8784  8784  8784  8784  8784  8784  8784
# ...       ...   ...   ...   ...   ...   ...   ...   ...
# V5792    8784  8784  8784  8784  8784  8784  8784  8784
# VMWBN    8784  8784  8784  8784  8784  8784  8784  8784
# XM44W    8784  8784  8784  8784  8784  8784  8784  8784
# ZFZUV    8784  8784  8784  8784  8784  8784  8784  8784
# ZWC6W    8784  8784  8784  8784  8784  8784  8784  8784
#
# [897 rows x 8 columns]

# %% [markdown]
# ### 1. shifting time by 24 hours for Ann Arbor

# %%
df_AA=df[df['station']=="KARB0"] #spliting off AA so I don't adjust its time.

# %%
df_AA
# Out:
#         station                time  temp  dwpt  rhum  prcp   wdir  wspd  \
# 2485872   KARB0 2021-10-15 00:00:00  17.8  16.7  93.0   0.0  230.0   5.4
# 2485873   KARB0 2021-10-15 01:00:00  17.2  15.5  90.0   0.0  260.0   7.6
# 2485874   KARB0 2021-10-15 02:00:00  16.1  14.5  90.0   0.0    0.0   0.0
# 2485875   KARB0 2021-10-15 03:00:00  16.7  14.3  86.0   0.0  350.0   9.4
# 2485876   KARB0 2021-10-15 04:00:00  16.1  15.0  93.0   0.0  220.0   7.6
# ...         ...                 ...   ...   ...   ...   ...    ...   ...
# 2494651   KARB0 2022-10-15 19:00:00  11.1  -0.1  46.0   0.0  210.0  24.1
# 2494652   KARB0 2022-10-15 20:00:00  11.1  -0.1  46.0   0.0  220.0  24.1
# 2494653   KARB0 2022-10-15 21:00:00  10.0  -0.5  48.0   0.0  220.0  20.5
# 2494654   KARB0 2022-10-15 22:00:00   8.0  -1.3  52.0   0.0  220.0   9.0
# 2494655   KARB0 2022-10-15 23:00:00   6.1  -1.1  60.0   0.0  190.0   7.6
#
#            pres
# 2485872  1012.2
# 2485873  1012.7
# 2485874  1012.9
# 2485875  1012.5
# 2485876  1013.2
# ...         ...
# 2494651  1013.2
# 2494652  1013.7
# 2494653  1013.8
# 2494654  1014.0
# 2494655  1014.3
#
# [8784 rows x 9 columns]

# %%
df_NOAA=df[df['station']!="KARB0"]

# %%
df_NOAA['time']=df_NOAA['time']+timedelta(hours=24) #adds 24
# Out:
# C:\Users\paull\AppData\Local\Temp\ipykernel_31720\4277429291.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_NOAA['time']=df_NOAA['time']+timedelta(hours=24) #adds 24

# %%
df_AA
# Out:
#         station                time  temp  dwpt  rhum  prcp   wdir  wspd  \
# 2485872   KARB0 2021-10-15 00:00:00  17.8  16.7  93.0   0.0  230.0   5.4
# 2485873   KARB0 2021-10-15 01:00:00  17.2  15.5  90.0   0.0  260.0   7.6
# 2485874   KARB0 2021-10-15 02:00:00  16.1  14.5  90.0   0.0    0.0   0.0
# 2485875   KARB0 2021-10-15 03:00:00  16.7  14.3  86.0   0.0  350.0   9.4
# 2485876   KARB0 2021-10-15 04:00:00  16.1  15.0  93.0   0.0  220.0   7.6
# ...         ...                 ...   ...   ...   ...   ...    ...   ...
# 2494651   KARB0 2022-10-15 19:00:00  11.1  -0.1  46.0   0.0  210.0  24.1
# 2494652   KARB0 2022-10-15 20:00:00  11.1  -0.1  46.0   0.0  220.0  24.1
# 2494653   KARB0 2022-10-15 21:00:00  10.0  -0.5  48.0   0.0  220.0  20.5
# 2494654   KARB0 2022-10-15 22:00:00   8.0  -1.3  52.0   0.0  220.0   9.0
# 2494655   KARB0 2022-10-15 23:00:00   6.1  -1.1  60.0   0.0  190.0   7.6
#
#            pres
# 2485872  1012.2
# 2485873  1012.7
# 2485874  1012.9
# 2485875  1012.5
# 2485876  1013.2
# ...         ...
# 2494651  1013.2
# 2494652  1013.7
# 2494653  1013.8
# 2494654  1014.0
# 2494655  1014.3
#
# [8784 rows x 9 columns]

# %%
#removing first day and last day 
#(manual current but could be automated)
df_AA24HR=pd.concat([df_AA,df_NOAA])
df_AA24HR=df_AA24HR[(df_AA24HR['time']>='2021-10-16 00:00:00') & (df_AA24HR['time']<='2022-10-14 23:00:00')]

# %%
#droping extra columns that we have determined are not part of the model
df_AA24HR.drop(columns=['prcp','wdir','wspd'], inplace=True)

# %% [markdown]
# ### 2. Clustering

# %%
#Scaling all values for kmeans - normalizing columns

scaler = StandardScaler() #read that standard scaler is probably best for knn vs min/max (first attempt)
scaler.fit(df_AA24HR.iloc[:,2:])
scaled=scaler.fit_transform(df_AA24HR.iloc[:,2:])
scaled_df=pd.DataFrame(scaled, columns = df_AA24HR.iloc[:2,2:].columns)
#normalized = preprocessing.normalize(df_AA24HR.iloc[:,2:9])
#normalized
#testknn=df_AA24HR[df_AA24HR['time']=='2022-01-02 1:00:00']
scaled_df=df_AA24HR.iloc[:,0:2].merge(scaled_df, left_index=True, right_index=True)


#testing
#scaled_df=scaled_df[scaled_df['time']<='2022-03-30 00:00:00']
scaled_df.dropna(inplace=True)

# %%
#creating a results DF
result_df=pd.DataFrame(scaled_df.station.unique(), columns=['station'])
result_df['total']=0
result_df['silhouette total']=0
result_df
# Out:
#     station  total  silhouette total
# 0     KARB0      0                 0
# 1     0CNUO      0                 0
# 2     0CO7B      0                 0
# 3     0FV1F      0                 0
# 4     1J1PJ      0                 0
# ..      ...    ...               ...
# 888   QHA0T      0                 0
# 889   SJZBK      0                 0
# 890   UJHR7      0                 0
# 891   UV7W2      0                 0
# 892   V5792      0                 0
#
# [893 rows x 3 columns]

# %%
station_loc = os.path.join(ROOT_DIR, 'station_analysis','AAstation.csv') #station data to get distance for comparision
dfstations=pd.read_csv(station_loc)

# %%
scaled_df.groupby('station').count()
# Out:
#          time  temp  dwpt  rhum  pres
# station
# 0CNUO    8736  8736  8736  8736  8736
# 0CO7B    8736  8736  8736  8736  8736
# 0FV1F    8736  8736  8736  8736  8736
# 1J1PJ    8736  8736  8736  8736  8736
# 1JWST    8736  8736  8736  8736  8736
# ...       ...   ...   ...   ...   ...
# QHA0T    8736  8736  8736  8736  8736
# SJZBK    8736  8736  8736  8736  8736
# UJHR7    8736  8736  8736  8736  8736
# UV7W2    8736  8736  8736  8736  8736
# V5792     864   864   864   864   864
#
# [893 rows x 5 columns]

# %%
#the actual kmeans
knn = KMeans(n_clusters=4) #need to tune this value and try other clustering (hierarchical) to find stable values
for t in tqdm(scaled_df.time.unique()): #looping through every hour
    dfhour=scaled_df[scaled_df['time']==t].copy()
    knndata=dfhour.iloc[:,2:]
    #print(t)
    knn.fit(knndata)
    y_kmeans = knn.predict(knndata)
    clusters=knn.labels_
    dfhour['cluster']=y_kmeans #finding clusters
    AAcluster=dfhour.loc[dfhour.station=='KARB0','cluster'].values[0] #finding cluster AA is in
    df_resulthr=dfhour[dfhour['cluster']==AAcluster].copy()
    df_resulthr['total']=1
    df_resulthr['silhouette total']=silhouette_score(knndata, clusters) #setting a threshold
    result_df=pd.concat([result_df, df_resulthr[['station','total','silhouette total']]]).groupby(['station']).sum().reset_index() #joining back to my results df.  I wasn't sure how else to do this.  
#result_df
# Out:
# 100%|██████████| 8736/8736 [21:11<00:00,  6.87it/s]

# %%
result_df['silhouette station average']=result_df['silhouette total']/result_df['total']

# %%
    #result_df.sort_values(by='total',ascending=False).head(60)
result=pd.merge(result_df,dfstations,left_on='station', right_on='id').sort_values(by='total',ascending=False) #top 20 locations (top will be AA)
result.head(50)
#result.to_csv('kmeansclustering2.csv')
# Out:
#     station  total  silhouette total  silhouette station average     id  \
# 206   KARB0   8736       2638.021689                    0.301971  KARB0
# 416   KMML0   6413       1952.779165                    0.304503  KMML0
# 325   KGAF0   5351       1633.464052                    0.305263  KGAF0
# 323   KFSW0   5326       1623.894513                    0.304899  KFSW0
# 208   KARV0   5310       1622.952282                    0.305641  KARV0
# 422   KMQB0   5308       1623.168940                    0.305797  KMQB0
# 418   KMNN0   5275       1611.187047                    0.305438  KMNN0
# 520   KTNU0   5272       1606.483724                    0.304720  KTNU0
# 524   KTVC0   5263       1607.049025                    0.305348  KTVC0
# 85    72420   5201       1592.025374                    0.306100  72420
# 330   KGHW0   5167       1583.517128                    0.306467  KGHW0
# 204                            Lima / Eastwood Estates      US     OH
# 526                         Indianapolis / Jolietville      US     IN
# 518                                              Tracy      US     MN
# 517                                              Mason      US     MI
# 326                              Granite Falls / Lorne      US     MN
# 324                                        Forest City      US     IA
# 212                                          Watertown      US     SD
# 413                                            Jackson      US     MN
# 414                           Mankato / Knollwood Park      US     MN
# 215                                         Washington      US     IA
# 322                                            Fosston      US     MN
# 528                             New Castle / Parkstown      US     PA
# 419      Mt Pleasant / Broadway Acres Mobile Home Park      US     MI
# 201                Ames / Old Orchard Mobile Home Park      US     IA
# 202                                     Angola / Flint      US     IN
# 327                               Grand Forks / Powell      US     ND
# 320               Charlotte / Meadows Mobile Home Park      US     MI
# 200                                      Alma / Eugene      US     MI
# 415                                    Omaha / Millard      US     NE
# 319                                            Bigfork      US     MN
# 210                         Ashland / Ashland Junction      US     WI
# 83                                   Munsing Lakeshore      US     MI
# 321                        Fairmont / Fairmont Estates      US     MN
# 521                                       Dodge Center      US     MN
# 410                      Minneapolis / Brooklyn Center      US     MN
# 214                                             Austin      US     MN
# 525                                Two Harbors / Waldo      US     MN
# 533                                  Wauseon / Ottokee      US     OH
# 426                              Muscatine / Fruitland      US     IA
# 421           Mount Pleasant / Woodside Mobile Estates      US     IA
# 530                         Chicago / Bancroft Corners      US     IL
# 417                 Menominee / Bayside Mobile Estates      US     MI
# 199                                Akron / Derby Downs      US     OH
# 328                                Grinnel / Westfield      US     IA
# 197                                           Atlantic      US     IA
# 412                             Marshalltown / Maulsby      US     IA
# 420                                             Morris      US     MN
# 218                         Wapakoneta / New Knoxville      US     OH
#
#          wmo  icao  ...  longitude  elevation                      timezone  \
# 206      NaN  KARB  ...   -83.7456      256.0               America/Detroit
# 416      NaN  KMML  ...   -95.8244      361.0               America/Chicago
# 325      NaN  KGAF  ...   -97.3709      251.0               America/Chicago
# 323      NaN  KFSW  ...   -91.3268      220.0               America/Chicago
# 208      NaN  KARV  ...   -89.7309      497.0               America/Chicago
# 422      NaN  KMQB  ...   -90.6524      215.0               America/Chicago
# 418      NaN  KMNN  ...   -83.0635      303.0              America/New_York
# 520      NaN  KTNU  ...   -93.0217      291.0               America/Chicago
# 524      NaN  KTVC  ...   -85.5824      190.0               America/Detroit
# 85   72420.0  KMFD  ...   -82.5166      395.0              America/New_York
# 330      NaN  KGHW  ...   -95.3204      425.0               America/Chicago
# 523      NaN  KTTF  ...   -83.4347      188.0               America/Detroit
# 204      NaN  KAOH  ...   -84.0271      297.0              America/New_York
# 526      NaN  KTYQ  ...   -86.2514      281.0  America/Indiana/Indianapolis
# 518      NaN  KTKC  ...   -95.6073      408.0               America/Chicago
# 517      NaN  KTEW  ...   -84.4232      280.0               America/Detroit
# 326      NaN  KGDB  ...   -95.5560      319.0               America/Chicago
# 324      NaN  KFXY  ...   -93.6241      375.0               America/Chicago
# 212      NaN  KATY  ...   -97.1547      533.0               America/Chicago
# 413      NaN  KMJQ  ...   -94.9865      441.0               America/Chicago
# 414      NaN  KMKT  ...   -93.9193      311.0             America/Menominee
# 215      NaN  KAWG  ...   -91.6752      230.0               America/Chicago
# 322      NaN  KFSE  ...   -95.7735      390.0               America/Chicago
# 528      NaN  KUCP  ...   -80.4134      326.0              America/New_York
# 419      NaN  KMOP  ...   -84.7373      230.0               America/Detroit
# 201      NaN  KAMW  ...   -93.6218      291.0               America/Chicago
# 202      NaN  KANQ  ...   -85.0835      303.0  America/Indiana/Indianapolis
# 327      NaN  KGFK  ...   -97.1738      257.0               America/Chicago
# 320      NaN  KFPK  ...   -84.8114      272.0               America/Detroit
# 200      NaN  KAMN  ...   -84.6879      230.0               America/Detroit
# 415      NaN  KMLE  ...   -96.1123      320.0               America/Chicago
# 319      NaN  KFOZ  ...   -93.6502      412.0               America/Chicago
# 210      NaN  KASX  ...   -90.9190      252.0               America/Chicago
# 83   72019.0  KP53  ...   -86.6500      187.0               America/Detroit
# 321      NaN  KFRM  ...   -94.4156      354.0               America/Chicago
# 521      NaN  KTOB  ...   -92.8315      398.0               America/Chicago
# 410      NaN  KMIC  ...   -93.3539      265.0               America/Chicago
# 214      NaN  KAUM  ...   -92.9329      376.0               America/Chicago
# 525      NaN  KTWM  ...   -91.7452      327.0               America/Chicago
# 533      NaN  KUSE  ...   -84.1272      238.0              America/New_York
# 426      NaN  KMUT  ...   -91.1482      167.0               America/Chicago
# 421      NaN  KMPZ  ...   -91.5111      223.0               America/Chicago
# 530      NaN  KUGN  ...   -87.8679      222.0               America/Chicago
# 417      NaN  KMNM  ...   -87.6384      191.0               America/Chicago
# 199      NaN  KAKR  ...   -81.4669      325.0              America/New_York
# 328      NaN  KGGI  ...   -92.7360      307.0               America/Chicago
# 197      NaN  KAIO  ...   -95.0487      355.0               America/Chicago
# 412      NaN  KMIW  ...   -92.9178      297.0               America/Chicago
# 420      NaN  KMOX  ...   -95.9672      346.0               America/Chicago
# 218      NaN  KAXV  ...   -84.2981      278.0              America/New_York
#
#     hourly_start  hourly_end daily_start   daily_end monthly_start  \
# 206   2006-01-01  2022-09-22  2006-01-01  2022-04-24    2006-01-01
# 416   2006-01-01  2022-09-22  2006-01-01  2022-04-24    2008-01-01
# 325   2010-11-18  2022-09-22  2010-11-19  2022-04-24    2014-01-01
# 323   2006-01-03  2022-09-22  2006-01-05  2022-04-24    2014-01-01
# 208   2006-01-01  2022-09-22  2006-01-01  2022-04-24    2009-01-01
# 422   2006-02-01  2022-09-22  2006-02-15  2022-04-24    2012-01-01
# 418   2006-01-01  2022-09-22  2006-01-01  2022-04-21    2006-01-01
# 520   2006-01-01  2022-09-22  2006-01-01  2022-04-24    2011-01-01
# 524   1973-01-01  2022-09-22  1973-01-02  2022-04-24    1981-01-01
# 85    2005-01-01  2022-09-22  1948-08-01  2022-09-14    1948-01-01
# 330   2006-01-01  2022-09-22  2006-01-01  2022-04-15    2006-01-01
# 218   2020-01-14  2022-09-22  2020-01-14  2022-04-24    2020-01-01
#
#     monthly_end milesfromstat
# 206  2022-01-01      0.000000
# 416  2022-01-01    627.132888
# 325  2022-01-01    787.526654
# 323  2021-01-01    408.045768
# 208  2022-01-01    392.465081
# 422  2022-01-01    377.657133
# 418  2022-01-01    116.402149
# 520  2022-01-01    479.185382
# 524  2022-01-01    196.855534
# 85   2022-01-01    115.837645
# 330  2022-01-01    623.196988
# 523  2022-01-01     25.244797
# 204  2022-01-01    105.602314
# 526  2022-01-01    199.936127
# 518  2022-01-01    614.213630
# 517  2022-01-01     41.971948
# 326  2022-01-01    618.157832
# 324  2022-01-01    507.231712
# 212  2022-01-01    697.344181
# 413  2022-01-01    578.106956
# 414  2022-01-01    531.437363
# 215  2022-01-01    414.855204
# 322  2022-01-01    695.849626
# 528  2022-01-01    191.304730
# 419  2022-01-01    108.863740
# 201  2022-01-01    507.546487
# 202  2022-01-01     79.841140
# 327  2022-01-01    765.085329
# 320  2022-01-01     59.678156
# 200  2022-01-01     89.732372
# 415  2022-01-01    642.877659
# 319  2022-01-01    617.913480
# 210  2022-01-01    463.723705
# 83   2022-01-01    323.315162
# 321  2022-01-01    549.611531
# 521  2022-01-01    475.588721
# 410  2021-01-01    519.649109
# 214  2022-01-01    476.135931
# 525  2021-01-01    515.861691
# 533  2022-01-01     46.650275
# 426  2022-01-01    386.712501
# 421  2022-01-01    411.734003
# 530  2021-01-01    211.571367
# 417  2022-01-01    279.641553
# 199  2022-01-01    143.569088
# 328  2022-01-01    464.213223
# 197  2022-01-01    585.888554
# 412  2021-01-01    470.786167
# 420  2022-01-01    651.540962
# 218  2022-01-01    122.753787
#
# [50 rows x 21 columns]

# %%
knn = KMeans(n_clusters=5)
dfhour=scaled_df[scaled_df['time']=='2022-08-30 10:00:00'].copy()
knndata=dfhour.iloc[:,2:]
knn.fit(knndata)
clusters=knn.labels_
silhouette_score(knndata, clusters)
# Out:
# 0.28295356741725497

# %%
result.head(26)
# Out:
#     station  total     id                                               name  \
# 206   KARB0   8736  KARB0                             Ann Arbor / Pittsfield
# 416   KMML0   6411  KMML0                                           Marshall
# 325   KGAF0   5340  KGAF0                                            Grafton
# 208   KARV0   5336  KARV0                                Minocqua / Woodruff
# 323   KFSW0   5327  KFSW0                 Fort Madison / Summit (Historical)
# 422   KMQB0   5301  KMQB0                                 Macomb / Good Hope
# 418   KMNN0   5287  KMNN0                        Marion / Logan (Historical)
# 524   KTVC0   5267  KTVC0  Traverse City / Treverse City [Misspelling] / ...
# 520   KTNU0   5266  KTNU0                  Newton / Coal Siding (Historical)
# 85    72420   5221  72420                                   Mansfield / Amoy
# 523   KTTF0   5182  KTTF0                         Monroe / Patterson Gardens
# 330   KGHW0   5165  KGHW0                          Glenwood / Pine Hill Park
# 204   KAOH0   5154  KAOH0                            Lima / Eastwood Estates
# 526   KTYQ0   5147  KTYQ0                         Indianapolis / Jolietville
# 518   KTKC0   5124  KTKC0                                              Tracy
# 517   KTEW0   5019  KTEW0                                              Mason
# 326   KGDB0   4983  KGDB0                              Granite Falls / Lorne
# 324   KFXY0   4939  KFXY0                                        Forest City
# 212   KATY0   4914  KATY0                                          Watertown
# 413   KMJQ0   4888  KMJQ0                                            Jackson
# 414   KMKT0   4874  KMKT0                           Mankato / Knollwood Park
# 215   KAWG0   4854  KAWG0                                         Washington
# 322   KFSE0   4851  KFSE0                                            Fosston
# 528   KUCP0   4820  KUCP0                             New Castle / Parkstown
# 419   KMOP0   4784  KMOP0      Mt Pleasant / Broadway Acres Mobile Home Park
# 201   KAMW0   4769  KAMW0                Ames / Old Orchard Mobile Home Park
#
#     country region      wmo  icao  latitude  longitude  elevation  \
# 206      US     MI      NaN  KARB   42.2230   -83.7456      256.0
# 416      US     MN      NaN  KMML   44.4517   -95.8244      361.0
# 325      US     ND      NaN  KGAF   48.4047   -97.3709      251.0
# 208      US     WI      NaN  KARV   45.9279   -89.7309      497.0
# 323      US     IA      NaN  KFSW   40.6593   -91.3268      220.0
# 422      US     IL      NaN  KMQB   40.5201   -90.6524      215.0
# 418      US     OH      NaN  KMNN   40.6163   -83.0635      303.0
# 524      US     MI      NaN  KTVC   44.7416   -85.5824      190.0
# 520      US     IA      NaN  KTNU   41.6744   -93.0217      291.0
# 85       US     OH  72420.0  KMFD   40.8214   -82.5166      395.0
# 523      US     MI      NaN  KTTF   41.9399   -83.4347      188.0
# 330      US     MN      NaN  KGHW   45.6439   -95.3204      425.0
# 204      US     OH      NaN  KAOH   40.7075   -84.0271      297.0
# 526      US     IN      NaN  KTYQ   40.0307   -86.2514      281.0
# 518      US     MN      NaN  KTKC   44.2491   -95.6073      408.0
# 517      US     MI      NaN  KTEW   42.5658   -84.4232      280.0
# 326      US     MN      NaN  KGDB   44.7533   -95.5560      319.0
# 324      US     IA      NaN  KFXY   43.2348   -93.6241      375.0
# 212      US     SD      NaN  KATY   44.9140   -97.1547      533.0
# 413      US     MN      NaN  KMJQ   43.6500   -94.9865      441.0
# 414      US     MN      NaN  KMKT   44.2228   -93.9193      311.0
# 215      US     IA      NaN  KAWG   41.2750   -91.6752      230.0
# 322      US     MN      NaN  KFSE   47.5928   -95.7735      390.0
# 528      US     PA      NaN  KUCP   41.0254   -80.4134      326.0
# 419      US     MI      NaN  KMOP   43.6216   -84.7373      230.0
# 201      US     IA      NaN  KAMW   41.9921   -93.6218      291.0
#
#                          timezone hourly_start  hourly_end daily_start  \
# 206               America/Detroit   2006-01-01  2022-09-22  2006-01-01
# 416               America/Chicago   2006-01-01  2022-09-22  2006-01-01
# 325               America/Chicago   2010-11-18  2022-09-22  2010-11-19
# 208               America/Chicago   2006-01-01  2022-09-22  2006-01-01
# 323               America/Chicago   2006-01-03  2022-09-22  2006-01-05
# 422               America/Chicago   2006-02-01  2022-09-22  2006-02-15
