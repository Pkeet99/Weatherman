# %% [markdown]
# ### Clustering to reduce features

# %%
import os
import pandas as pd
from datetime import datetime, timedelta
from sklearn.neighbors import KNeighborsClassifier
from sklearn.cluster import KMeans
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from tqdm import tqdm
from sklearn.metrics.cluster import silhouette_score

# %%
ROOT_DIR = os.path.realpath(os.path.join(os.getcwd(), '..'))
cln_pkl_loc = os.path.join(ROOT_DIR, 'data','cleanweathersmall.pkl')

# %%
df = pd.read_pickle(cln_pkl_loc)
df.groupby('station').count()
# Out:
#          time  temp  dwpt  rhum  prcp  wdir  wspd  pres
# station
# 0CNUO    8784  8784  8784  8784  8784  8784  8784  8784
# 0CO7B    8784  8784  8784  8784  8784  8784  8784  8784
# 0FV1F    8784  8784  8784  8784  8784  8784  8784  8784
# 1J1PJ    8784  8784  8784  8784  8784  8784  8784  8784
# 1JWST    8784  8784  8784  8784  8784  8784  8784  8784
# ...       ...   ...   ...   ...   ...   ...   ...   ...
# V5792    8784  8784  8784  8784  8784  8784  8784  8784
# VMWBN    8784  8784  8784  8784  8784  8784  8784  8784
# XM44W    8784  8784  8784  8784  8784  8784  8784  8784
# ZFZUV    8784  8784  8784  8784  8784  8784  8784  8784
# ZWC6W    8784  8784  8784  8784  8784  8784  8784  8784
#
# [897 rows x 8 columns]

# %% [markdown]
# ### 1. shifting time by 24 hours for Ann Arbor

# %%
df_AA=df[df['station']=="KARB0"] #spliting off AA so I don't adjust its time.

# %%
df_AA
# Out:
#         station                time  temp  dwpt  rhum  prcp   wdir  wspd  \
# 2485872   KARB0 2021-10-15 00:00:00  17.8  16.7  93.0   0.0  230.0   5.4
# 2485873   KARB0 2021-10-15 01:00:00  17.2  15.5  90.0   0.0  260.0   7.6
# 2485874   KARB0 2021-10-15 02:00:00  16.1  14.5  90.0   0.0    0.0   0.0
# 2485875   KARB0 2021-10-15 03:00:00  16.7  14.3  86.0   0.0  350.0   9.4
# 2485876   KARB0 2021-10-15 04:00:00  16.1  15.0  93.0   0.0  220.0   7.6
# ...         ...                 ...   ...   ...   ...   ...    ...   ...
# 2494651   KARB0 2022-10-15 19:00:00  11.1  -0.1  46.0   0.0  210.0  24.1
# 2494652   KARB0 2022-10-15 20:00:00  11.1  -0.1  46.0   0.0  220.0  24.1
# 2494653   KARB0 2022-10-15 21:00:00  10.0  -0.5  48.0   0.0  220.0  20.5
# 2494654   KARB0 2022-10-15 22:00:00   8.0  -1.3  52.0   0.0  220.0   9.0
# 2494655   KARB0 2022-10-15 23:00:00   6.1  -1.1  60.0   0.0  190.0   7.6
#
#            pres
# 2485872  1012.2
# 2485873  1012.7
# 2485874  1012.9
# 2485875  1012.5
# 2485876  1013.2
# ...         ...
# 2494651  1013.2
# 2494652  1013.7
# 2494653  1013.8
# 2494654  1014.0
# 2494655  1014.3
#
# [8784 rows x 9 columns]

# %%
df_NOAA=df[df['station']!="KARB0"]

# %%
df_NOAA['time']=df_NOAA['time']+timedelta(hours=24) #adds 24
# Out:
# C:\Users\paull\AppData\Local\Temp\ipykernel_32892\4277429291.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_NOAA['time']=df_NOAA['time']+timedelta(hours=24) #adds 24

# %%
df_AA
# Out:
#         station                time  temp  dwpt  rhum  prcp   wdir  wspd  \
# 2485872   KARB0 2021-10-15 00:00:00  17.8  16.7  93.0   0.0  230.0   5.4
# 2485873   KARB0 2021-10-15 01:00:00  17.2  15.5  90.0   0.0  260.0   7.6
# 2485874   KARB0 2021-10-15 02:00:00  16.1  14.5  90.0   0.0    0.0   0.0
# 2485875   KARB0 2021-10-15 03:00:00  16.7  14.3  86.0   0.0  350.0   9.4
# 2485876   KARB0 2021-10-15 04:00:00  16.1  15.0  93.0   0.0  220.0   7.6
# ...         ...                 ...   ...   ...   ...   ...    ...   ...
# 2494651   KARB0 2022-10-15 19:00:00  11.1  -0.1  46.0   0.0  210.0  24.1
# 2494652   KARB0 2022-10-15 20:00:00  11.1  -0.1  46.0   0.0  220.0  24.1
# 2494653   KARB0 2022-10-15 21:00:00  10.0  -0.5  48.0   0.0  220.0  20.5
# 2494654   KARB0 2022-10-15 22:00:00   8.0  -1.3  52.0   0.0  220.0   9.0
# 2494655   KARB0 2022-10-15 23:00:00   6.1  -1.1  60.0   0.0  190.0   7.6
#
#            pres
# 2485872  1012.2
# 2485873  1012.7
# 2485874  1012.9
# 2485875  1012.5
# 2485876  1013.2
# ...         ...
# 2494651  1013.2
# 2494652  1013.7
# 2494653  1013.8
# 2494654  1014.0
# 2494655  1014.3
#
# [8784 rows x 9 columns]

# %%
#removing first day and last day 
#(manual current but could be automated)
df_AA24HR=pd.concat([df_AA,df_NOAA])
df_AA24HR=df_AA24HR[(df_AA24HR['time']>='2021-10-16 00:00:00') & (df_AA24HR['time']<='2022-10-14 23:00:00')]

# %%
#droping extra columns that we have determined are not part of the model
df_AA24HR.drop(columns=['prcp','wdir','wspd'], inplace=True)

# %% [markdown]
# ### 2. Clustering

# %%
#Scaling all values for kmeans - normalizing columns

scaler = StandardScaler() #read that standard scaler is probably best for knn vs min/max (first attempt)
scaler.fit(df_AA24HR.iloc[:,2:])
scaled=scaler.fit_transform(df_AA24HR.iloc[:,2:])
scaled_df=pd.DataFrame(scaled, columns = df_AA24HR.iloc[:2,2:].columns)
#normalized = preprocessing.normalize(df_AA24HR.iloc[:,2:9])
#normalized
#testknn=df_AA24HR[df_AA24HR['time']=='2022-01-02 1:00:00']
scaled_df=df_AA24HR.iloc[:,0:2].merge(scaled_df, left_index=True, right_index=True)


#testing
#scaled_df=scaled_df[scaled_df['time']<='2022-03-30 00:00:00']

# %%
#creating a results DF
result_df=pd.DataFrame(scaled_df.station.unique(), columns=['station'])
result_df['total']=0
result_df
# Out:
#     station  total
# 0     KARB0      0
# 1     0CNUO      0
# 2     0CO7B      0
# 3     0FV1F      0
# 4     1J1PJ      0
# ..      ...    ...
# 888   QHA0T      0
# 889   SJZBK      0
# 890   UJHR7      0
# 891   UV7W2      0
# 892   V5792      0
#
# [893 rows x 2 columns]

# %%
station_loc = os.path.join(ROOT_DIR, 'station_analysis','AAstation.csv') #station data to get distance for comparision
dfstations=pd.read_csv(station_loc)

# %%
scaled_df.groupby('station').count()
# Out:
#          time  temp  dwpt  rhum  pres
# station
# 0CNUO    8736  8736  8736  8736  8736
# 0CO7B    8736  8736  8736  8736  8736
# 0FV1F    8736  8736  8736  8736  8736
# 1J1PJ    8736  8736  8736  8736  8736
# 1JWST    8736  8736  8736  8736  8736
# ...       ...   ...   ...   ...   ...
# QHA0T    8736  8736  8736  8736  8736
# SJZBK    8736  8736  8736  8736  8736
# UJHR7    8736  8736  8736  8736  8736
# UV7W2    8736  8736  8736  8736  8736
# V5792     864   864   864   864   864
#
# [893 rows x 5 columns]

# %%
#the actual kmeans
knn = KMeans(n_clusters=4) #need to tune this value and try other clustering (hierarchical) to find stable values
for t in tqdm(scaled_df.time.unique()): #looping through every hour
    dfhour=scaled_df[scaled_df['time']==t].copy()
    knndata=dfhour.iloc[:,2:]
    #print(t)
    knn.fit(knndata)
    y_kmeans = knn.predict(knndata)
    dfhour['cluster']=y_kmeans #finding clusters
    AAcluster=dfhour.loc[dfhour.station=='KARB0','cluster'].values[0] #finding cluster AA is in
    df_resulthr=dfhour[dfhour['cluster']==AAcluster].copy()
    df_resulthr['total']=1 #setting a threshold
    result_df=pd.concat([result_df, df_resulthr[['station','total']]]).groupby(['station']).sum().reset_index() #joining back to my results df.  I wasn't sure how else to do this.  
result_df
# Out:
#  99%|█████████▉| 8688/8736 [16:42<00:05,  8.96it/s]

# %%
    #result_df.sort_values(by='total',ascending=False).head(60)
result=pd.merge(result_df,dfstations,left_on='station', right_on='id').sort_values(by='total',ascending=False) #top 20 locations (top will be AA)
result.head(50)
#result.to_csv('kmeansclustering.csv')
# Out:
#     station  total     id                                               name  \
# 206   KARB0  17472  KARB0                             Ann Arbor / Pittsfield
# 416   KMML0  12831  KMML0                                           Marshall
# 325   KGAF0  10708  KGAF0                                            Grafton
# 323   KFSW0  10669  KFSW0                 Fort Madison / Summit (Historical)
# 208   KARV0  10659  KARV0                                Minocqua / Woodruff
# 422   KMQB0  10584  KMQB0                                 Macomb / Good Hope
# 418   KMNN0  10562  KMNN0                        Marion / Logan (Historical)
# 524   KTVC0  10532  KTVC0  Traverse City / Treverse City [Misspelling] / ...
# 520   KTNU0  10526  KTNU0                  Newton / Coal Siding (Historical)
# 85    72420  10415  72420                                   Mansfield / Amoy
# 523   KTTF0  10377  KTTF0                         Monroe / Patterson Gardens
# 330   KGHW0  10322  KGHW0                          Glenwood / Pine Hill Park
# 526   KTYQ0  10318  KTYQ0                         Indianapolis / Jolietville
# 204   KAOH0  10302  KAOH0                            Lima / Eastwood Estates
# 518   KTKC0  10264  KTKC0                                              Tracy
# 517   KTEW0  10022  KTEW0                                              Mason
# 326   KGDB0   9964  KGDB0                              Granite Falls / Lorne
# 324   KFXY0   9866  KFXY0                                        Forest City
# 212   KATY0   9848  KATY0                                          Watertown
# 413   KMJQ0   9765  KMJQ0                                            Jackson
# 414   KMKT0   9750  KMKT0                           Mankato / Knollwood Park
# 215   KAWG0   9724  KAWG0                                         Washington
# 322   KFSE0   9709  KFSE0                                            Fosston
# 528   KUCP0   9629  KUCP0                             New Castle / Parkstown
# 419   KMOP0   9574  KMOP0      Mt Pleasant / Broadway Acres Mobile Home Park
# 201   KAMW0   9535  KAMW0                Ames / Old Orchard Mobile Home Park
# 202   KANQ0   9515  KANQ0                                     Angola / Flint
# 327   KGFK0   9464  KGFK0                               Grand Forks / Powell
# 320   KFPK0   9391  KFPK0               Charlotte / Meadows Mobile Home Park
# 200   KAMN0   9337  KAMN0                                      Alma / Eugene
# 319   KFOZ0   9298  KFOZ0                                            Bigfork
# 415   KMLE0   9291  KMLE0                                    Omaha / Millard
# 210   KASX0   9283  KASX0                         Ashland / Ashland Junction
# 83    72019   9173  72019                                  Munsing Lakeshore
# 321   KFRM0   9170  KFRM0                        Fairmont / Fairmont Estates
# 521   KTOB0   9127  KTOB0                                       Dodge Center
# 214   KAUM0   9076  KAUM0                                             Austin
# 410   KMIC0   9068  KMIC0                      Minneapolis / Brooklyn Center
# 525   KTWM0   9061  KTWM0                                Two Harbors / Waldo
# 426   KMUT0   9040  KMUT0                              Muscatine / Fruitland
# 533   KUSE0   9027  KUSE0                                  Wauseon / Ottokee
# 421   KMPZ0   8940  KMPZ0           Mount Pleasant / Woodside Mobile Estates
# 417   KMNM0   8878  KMNM0                 Menominee / Bayside Mobile Estates
# 199   KAKR0   8865  KAKR0                                Akron / Derby Downs
# 530   KUGN0   8859  KUGN0                         Chicago / Bancroft Corners
# 197   KAIO0   8858  KAIO0                                           Atlantic
# 412   KMIW0   8836  KMIW0                             Marshalltown / Maulsby
# 328   KGGI0   8829  KGGI0                                Grinnel / Westfield
# 218   KAXV0   8769  KAXV0                         Wapakoneta / New Knoxville
# 420   KMOX0   8755  KMOX0                                             Morris
#
#     country region      wmo  icao  latitude  longitude  elevation  \
# 206      US     MI      NaN  KARB   42.2230   -83.7456      256.0
# 416      US     MN      NaN  KMML   44.4517   -95.8244      361.0
# 325      US     ND      NaN  KGAF   48.4047   -97.3709      251.0
# 323      US     IA      NaN  KFSW   40.6593   -91.3268      220.0
# 208      US     WI      NaN  KARV   45.9279   -89.7309      497.0
# 422      US     IL      NaN  KMQB   40.5201   -90.6524      215.0
# 418      US     OH      NaN  KMNN   40.6163   -83.0635      303.0
# 524      US     MI      NaN  KTVC   44.7416   -85.5824      190.0
# 520      US     IA      NaN  KTNU   41.6744   -93.0217      291.0
# 85       US     OH  72420.0  KMFD   40.8214   -82.5166      395.0
# 523      US     MI      NaN  KTTF   41.9399   -83.4347      188.0
# 330      US     MN      NaN  KGHW   45.6439   -95.3204      425.0
# 526      US     IN      NaN  KTYQ   40.0307   -86.2514      281.0
# 204      US     OH      NaN  KAOH   40.7075   -84.0271      297.0
# 518      US     MN      NaN  KTKC   44.2491   -95.6073      408.0
# 517      US     MI      NaN  KTEW   42.5658   -84.4232      280.0
# 326      US     MN      NaN  KGDB   44.7533   -95.5560      319.0
# 324      US     IA      NaN  KFXY   43.2348   -93.6241      375.0
# 212      US     SD      NaN  KATY   44.9140   -97.1547      533.0
# 219   KAZO0   5909  KAZO0  Kalamazoo / Colonial Acres Mobile Home Park
# 209   KASW0   5855  KASW0                            Warsaw / Monoquet
# 213   KAUH0   5807  KAUH0                                       Aurora
# 478   KPWC0   5720  KPWC0                                   Pine River
# 215   KAWG0   5703  KAWG0                                   Washington
# 483   KRCX0   5700  KRCX0                             Ladysmith / Tony
# 200   KAMN0   5695  KAMN0                                Alma / Eugene
# 216   KAXA0   5685  KAXA0                            Algona / Hobarton
# 464   KPHD0   5672  KPHD0       New Philadelphia / Schoenbrunn Estates
# 196   KAIG0   5631  KAIG0                                       Antigo
# 214   KAUM0   5623  KAUM0                                       Austin
# 486   KRHI0   5617  KRHI0                                  Rhinelander
# 477   KPVB0   5617  KPVB0                        Platteville / Ipswich
# 466   KPJC0   5603  KPJC0                     Zelienople / Old Furnace
# 461   KPDC0   5601  KPDC0   Prairie Du Chien / Selchs Mobile Home Park
# 463   KPEX0   5598  KPEX0                                  Paynesville
# 488   KRNH0   5590  KRNH0      New Richmond / Woodbridge Trailer Court
#
#     country region  wmo  icao  latitude  longitude  elevation  \
# 206      US     MI  NaN  KARB   42.2230   -83.7456      256.0
# 208      US     WI  NaN  KARV   45.9279   -89.7309      497.0
# 472      US     IL  NaN  KPNT   40.9244   -88.6239      203.0
# 471      US     MN  NaN  KPNM   45.5599   -93.6082      299.0
# 470      US     NE  NaN  KPMV   40.9484   -95.9174      367.0
# 207      US     IL  NaN  KARR   41.7719   -88.4757      217.0
# 205      US     MN  NaN  KAQP   45.2275   -96.0043      311.0
# 469      US     MI  NaN  KPLN   45.5709   -84.7967      220.0
# 202      US     IN  NaN  KANQ   41.6397   -85.0835      303.0
# 219      US     MI  NaN  KAZO   42.2344   -85.5516      266.0
# 209      US     IN  NaN  KASW   41.2747   -85.8401      259.0
# 213      US     NE  NaN  KAUH   40.8941   -97.9946      550.0
# 478      US     MN  NaN  KPWC   46.7248   -94.3817      395.0
# 215      US     IA  NaN  KAWG   41.2750   -91.6752      230.0
# 483      US     WI  NaN  KRCX   45.4968   -91.0005      378.0
# 200      US     MI  NaN  KAMN   43.3221   -84.6879      230.0
# 216      US     IA  NaN  KAXA   43.0779   -94.2720      371.0
# 464      US     OH  NaN  KPHD   40.4702   -81.4199      273.0
# 196      US     WI  NaN  KAIG   45.1542   -89.1107      464.0
# 214      US     MN  NaN  KAUM   43.6626   -92.9329      376.0
# 486      US     WI  NaN  KRHI   45.6309   -89.4666      495.0
# 477      US     WI  NaN  KPVB   42.6894   -90.4444      312.0
# 466      US     PA  NaN  KPJC   40.8020   -80.1609      274.0
# 461      US     WI  NaN  KPDC   43.0193   -91.1237      201.0
# 463      US     MN  NaN  KPEX   45.3721   -94.7447      361.0
# 488      US     WI  NaN  KRNH   45.1478   -92.5392      304.0
#
#                          timezone hourly_start  hourly_end daily_start  \
# 206               America/Detroit   2006-01-01  2022-09-22  2006-01-01
# 208               America/Chicago   2006-01-01  2022-09-22  2006-01-01
# 472               America/Chicago   2006-09-26  2022-09-22  2011-03-18
