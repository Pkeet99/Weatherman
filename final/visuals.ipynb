# %%
import altair as alt
import pandas as pd
import os

# %%
ROOT_DIR = os.path.realpath(os.path.join(os.getcwd(), '..'))
xt_db_km = os.path.join(ROOT_DIR, 'final','Extra_Tree_results_other_stations(db_km_scan_cluster).csv')
xt_km = os.path.join(ROOT_DIR, 'final','Extra_Tree_results_other_stations(initial_cluster).csv')
xt = os.path.join(ROOT_DIR, 'final','Extra_Tree_results_other_stations.csv')
xt_db = os.path.join(ROOT_DIR, 'final','Extra_Tree_results_other_stations(db_scan_cluster).csv')
xt_km_wf = os.path.join(ROOT_DIR, 'final','Extra_Tree_results_other_stations(initial clusters-walk forward).csv')
results = os.path.join(ROOT_DIR, 'Results','Extra_Tree_results.csv')
res = pd.read_csv(results)
res.columns = ('time', 'aa_only','actual')
res

files = [(xt,'xt'), (xt_km,'xt_km'), (xt_km_wf,'xt_km_wf'), (xt_db,'xt_db'), (xt_db_km,'xt_db_km')]
for file,name in files:
    df = pd.read_csv(file)
    df.columns = ('time', name)
    res = res.merge(df, on='time',how='outer')

res
# Out:
#                      time    aa_only  actual      xt   xt_km  xt_km_wf  \
# 0     2022-09-01 00:00:00  21.776073    22.8  22.800  22.800      22.8
# 1     2022-09-01 01:00:00  17.992501    20.0  18.956  18.098      20.0
# 2     2022-09-01 02:00:00  16.406189    18.9  16.876  17.388      18.9
# 3     2022-09-01 03:00:00  15.960311    16.1  15.956  17.653      16.1
# 4     2022-09-01 04:00:00  14.559724    15.0  15.326  16.221      15.0
# ...                   ...        ...     ...     ...     ...       ...
# 1075  2022-10-15 19:00:00  13.713431    11.1     NaN     NaN       NaN
# 1076  2022-10-15 20:00:00  13.463651    11.1     NaN     NaN       NaN
# 1077  2022-10-15 21:00:00  12.978065    10.0     NaN     NaN       NaN
# 1078  2022-10-15 22:00:00  11.919945     8.0     NaN     NaN       NaN
# 1079  2022-10-15 23:00:00   9.912796     6.1     NaN     NaN       NaN
#
#        xt_db  xt_db_km
# 0     22.800    22.800
# 1     21.533    19.289
# 2     22.189    16.215
# 3     21.239    16.367
# 4     20.099    15.325
# ...      ...       ...
# 1075     NaN       NaN
# 1076     NaN       NaN
# 1077     NaN       NaN
# 1078     NaN       NaN
# 1079     NaN       NaN
#
# [1080 rows x 8 columns]

# %%
res.dropna(inplace=True)
res.melt(id_vars='time')
# Out:
#                      time  variable      value
# 0     2022-09-01 00:00:00   aa_only  21.776073
# 1     2022-09-01 01:00:00   aa_only  17.992501
# 2     2022-09-01 02:00:00   aa_only  16.406189
# 3     2022-09-01 03:00:00   aa_only  15.960311
# 4     2022-09-01 04:00:00   aa_only  14.559724
# ...                   ...       ...        ...
# 7471  2022-10-15 07:00:00  xt_db_km   2.412000
# 7472  2022-10-15 08:00:00  xt_db_km   2.200000
# 7473  2022-10-15 09:00:00  xt_db_km   1.605000
# 7474  2022-10-15 10:00:00  xt_db_km   1.394000
# 7475  2022-10-15 11:00:00  xt_db_km   2.398000
#
# [7476 rows x 3 columns]

# %%
alt.data_transformers.disable_max_rows()
alt.Chart(res[['time','actual','aa_only']].melt(id_vars='time')).mark_line(size=1).encode(
    x=alt.X('time:T', axis=alt.Axis(tickSize=0, labelFontSize=12),title=None),
    y=alt.Y('value:Q',title='Temperature'),
    color=alt.Color('variable',legend=alt.Legend(title='Model')),
    strokeDash='variable'
).properties(
    height=400,
    width=800,
    title={
      "text": ['Extra Trees Regression Model Comparisons'], 
      "subtitle": ["Ann Arbor only Sept 1 - Oct 15"],
      "color": "black",
      "subtitleColor": "gray"
    }
)
# Out:
# alt.Chart(...)

# %%
alt.data_transformers.disable_max_rows()
alt.Chart(res[['time','xt','actual']].melt(id_vars='time')).mark_line(size=1).encode(
    x=alt.X('time:T', axis=alt.Axis(tickSize=0, labelFontSize=12),title=None),
    y=alt.Y('value:Q',title='Temperature'),
    color=alt.Color('variable',legend=alt.Legend(title='Model')),
    strokeDash='variable'
).properties(
    height=400,
    width=800,
    title={
      "text": ['Extra Trees Regression Model Comparisons'], 
      "subtitle": ["All other stations included Sept 1 - Oct 15"],
      "color": "black",
      "subtitleColor": "gray"
    }
)
# Out:
# alt.Chart(...)

# %%
alt.data_transformers.disable_max_rows()
alt.Chart(res[['time','xt_km','actual']].melt(id_vars='time')).mark_line(size=1).encode(
    x=alt.X('time:T', axis=alt.Axis(tickSize=0, labelFontSize=12),title=None),
    y=alt.Y('value:Q',title='Temperature'),
    color=alt.Color('variable',legend=alt.Legend(title='Model')),
    strokeDash='variable'
).properties(
    height=400,
    width=800,
    title={
      "text": ['Extra Trees Regression Model Comparisons'], 
      "subtitle": ["Stations trimmed with k-means clustering Sept 1 - Oct 15"],
      "color": "black",
      "subtitleColor": "gray"
    }
)
# Out:
# alt.Chart(...)

# %%
alt.data_transformers.disable_max_rows()
alt.Chart(res[['time','xt_db','actual']].melt(id_vars='time')).mark_line(size=1).encode(
    x=alt.X('time:T', axis=alt.Axis(tickSize=0, labelFontSize=12),title=None),
    y=alt.Y('value:Q',title='Temperature'),
    color=alt.Color('variable',legend=alt.Legend(title='Model')),
    strokeDash='variable'
).properties(
    height=400,
    width=800,
    title={
      "text": ['Extra Trees Regression Model Comparisons'], 
      "subtitle": ["Stations trimmed with DBSCAN clustering Sept 1 - Oct 15"],
      "color": "black",
      "subtitleColor": "gray"
    }
)
# Out:
# alt.Chart(...)

# %%
alt.data_transformers.disable_max_rows()
alt.Chart(res[['time','xt_db_km','actual']].melt(id_vars='time')).mark_line(size=1).encode(
    x=alt.X('time:T', axis=alt.Axis(tickSize=0, labelFontSize=12),title=None),
    y=alt.Y('value:Q',title='Temperature'),
    color=alt.Color('variable',legend=alt.Legend(title='Model')),
    strokeDash='variable'
).properties(
    height=400,
    width=800,
    title={
      "text": ['Extra Trees Regression Model Comparisons'], 
      "subtitle": ["Stations trimmed with k-means/DBSCAN clustering Sept 1 - Oct 15"],
      "color": "black",
      "subtitleColor": "gray"
    }
)
# Out:
# alt.Chart(...)
