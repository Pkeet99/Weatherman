# %% [markdown]
# # Ann Arbor Only Supervised models
#
# ## General Imports

# %%
import os
import pandas as pd
from sklearn.ensemble import ExtraTreesRegressor
from sklearn import linear_model
from sklearn.dummy import DummyRegressor
import altair as alt
from sklearn.model_selection import cross_val_score
from skopt.space import Integer
from skopt.utils import use_named_args
import numpy as np
from skopt import gp_minimize
from skopt.plots import plot_convergence
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_validate
from sklearnex import patch_sklearn
patch_sklearn()
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %% [markdown]
# ## Small dataset (2022 only)
# ### Get cleaned data from pickle file

# %%
# ROOT_DIR = os.path.realpath(os.path.join(os.getcwd(), '..'))
# cln_pkl_loc = os.path.join(ROOT_DIR, 'data','cleanweathersmall.pkl')
# df = pd.read_pickle(cln_pkl_loc)

# %%
# df.info()

# %% [markdown]
# ### Basic data cleaning to build necessary features

# %%
# pivoted_df = df.pivot(index='time', columns='station', values=['temp', 'dwpt','rhum','prcp','wdir','wspd','pres'])
# pivoted_df.columns = ['_'.join(col) for col in pivoted_df.columns.values]
# pivoted_df

# %% [markdown]
# ### Our target is Ann Arbor which is station __"KARB0"__, so pulling those features out of the df

# %%
# ann_arbor_cols = [col for col in pivoted_df.columns if "KARB0" in col]
# ann_arbor_df = pivoted_df[ann_arbor_cols].copy()

# %% [markdown]
# ### Our target we want to predict is the weather 24 hours in the future, so need to duplicate and shift the features. And do some more basic cleaning

# %%
# for col in ann_arbor_df.columns:
#     ann_arbor_df[f'24 hr~{col}'] = ann_arbor_df[col].shift(-24)
# ann_arbor_df = ann_arbor_df.rename_axis(None, axis = 0)
# ann_arbor_df = ann_arbor_df[ann_arbor_df['24 hr~temp_KARB0'].notna()]
# ann_arbor_df

# %%
ROOT_DIR = os.path.realpath(os.path.join(os.getcwd(), '..'))
aa_pkl_loc = os.path.join(ROOT_DIR, 'data','data','aa_historical.pkl')
df = pd.read_pickle(aa_pkl_loc)
df.drop(columns=['snow', 'wpgt','tsun','coco','Year'],inplace=True)
df = df[df.columns[:7]]
for col in df.columns:
    df[col] = df[col].interpolate(method ='linear', limit_direction ='forward')
    df[f'24hr~{col}'] = df[col].shift(-24)
df = df[df['24hr~temp'].notna()]
df = df[df.index > '2022']
df = df[df.index < '2022-10-15']
ann_arbor_df = df.rename_axis(None, axis = 0)
ann_arbor_df
# Out:
#                      temp  dwpt  rhum  prcp   wdir  wspd    pres  24hr~temp  \
# 2022-01-01 01:00:00   5.0   2.9  86.0   0.0  120.0  11.2  1005.4       -2.8
# 2022-01-01 02:00:00   5.0   2.9  86.0   0.0  120.0   5.4  1005.3       -3.3
# 2022-01-01 03:00:00   5.0   2.9  86.0   0.0    0.0   0.0  1004.9       -3.9
# 2022-01-01 04:00:00   5.6   3.3  85.0   0.0    0.0   0.0  1004.9       -4.4
# 2022-01-01 05:00:00   5.6   2.8  82.0   0.0    0.0   0.0  1005.3       -4.4
# ...                   ...   ...   ...   ...    ...   ...     ...        ...
# 2022-10-14 19:00:00  15.0  -3.4  28.0   0.0  220.0  19.0  1006.0       11.1
# 2022-10-14 20:00:00  13.9  -4.3  28.0   0.0  220.0  27.7  1006.7       11.1
# 2022-10-14 21:00:00  12.8  -5.8  27.0   0.0  200.0  18.4  1007.3       10.0
# 2022-10-14 22:00:00  11.0  -5.1  32.0   0.0  190.0   9.0  1008.0        8.0
# 2022-10-14 23:00:00   8.9  -5.8  35.0   0.0  120.0   9.4  1008.1        6.1
#
#                      24hr~dwpt  24hr~rhum  24hr~prcp  24hr~wdir  24hr~wspd  \
# 2022-01-01 01:00:00       -5.6       81.0        0.7       30.0       16.6
# 2022-01-01 02:00:00       -5.6       84.0        0.4       30.0       24.1
# 2022-01-01 03:00:00       -6.1       85.0        0.3       20.0       18.4
# 2022-01-01 04:00:00       -6.1       88.0        0.3       30.0       16.6
# 2022-01-01 05:00:00       -6.1       88.0        0.3       20.0       18.4
# ...                        ...        ...        ...        ...        ...
# 2022-10-14 19:00:00       -0.1       46.0        0.0      210.0       24.1
# 2022-10-14 20:00:00       -0.1       46.0        0.0      220.0       24.1
# 2022-10-14 21:00:00       -0.5       48.0        0.0      220.0       20.5
# 2022-10-14 22:00:00       -1.3       52.0        0.0      220.0        9.0
# 2022-10-14 23:00:00       -1.1       60.0        0.0      190.0        7.6
#
#                      24hr~pres
# 2022-01-01 01:00:00     1010.2
# 2022-01-01 02:00:00     1009.9
# 2022-01-01 03:00:00     1010.3
# 2022-01-01 04:00:00     1010.1
# 2022-01-01 05:00:00     1009.6
# ...                        ...
# 2022-10-14 19:00:00     1013.2
# 2022-10-14 20:00:00     1013.7
# 2022-10-14 21:00:00     1013.8
# 2022-10-14 22:00:00     1014.0
# 2022-10-14 23:00:00     1014.3
#
# [6887 rows x 14 columns]

# %% [markdown]
# ### Now our target will be the '-24hr~temp_KARB0' column, and our features to use in our first prediction model will be all of the measurements at station "KARB0" 24 hours prior to our target.
# This cell will run 5 fold cross-validate on our 3 chosen regression models (Extra Trees Regressor, Lasso Regressor, and Tweedie Regressor). This will show how the average accuracy scores compare across these models on this data set.

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
X_cols = [col for col in ann_arbor_df.columns if "~" not in col]
X = ann_arbor_df[X_cols]

# played with idea of scaling, but minimal impact found
# from sklearn.preprocessing import RobustScaler
# transformer = RobustScaler().fit(X)
# X = transformer.transform(X)

# y = ann_arbor_df['24 hr~temp_KARB0']
y = ann_arbor_df['24hr~temp']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=696)
xt_reg = ExtraTreesRegressor(random_state=696,n_jobs=-1)
lasso_reg = linear_model.Lasso(alpha=0.1)
tw_reg = linear_model.TweedieRegressor()
dummy_reg = DummyRegressor(strategy="median")
models = {'Extra Trees Regressor':xt_reg,
          'Lasso Regressor':lasso_reg,
          'Tweedie Regressor':tw_reg,
          'Dummy Regressor':dummy_reg}
for key, value in models.items():
    # value = make_pipeline(StandardScaler(), value)
    cv_results = cross_validate(value, X_train, y_train, cv=5,n_jobs=-1)
    print(key)
    print("Mean accuracy score: ", end="")
    print(round(cv_results['test_score'].mean(),3), end="")
    print(", best accuracy score: ", end="")
    print(round(cv_results['test_score'].max(),3), end="")
    print(", with std dev of: ", end="")
    print(round(cv_results['test_score'].std(),3))
    print("Mean training time: ", end="")
    print(round(cv_results['score_time'].mean(),3))
    print(f"Score on hold out set: {round(value.fit(X_train, y_train).score(X_test, y_test),3)}")
    print(f"Score on time sensitive hold out set: {round(value.fit(X[:-1055], y[:-1055]).score(X[-1055:], y[-1055:]),3)}")
    print("**************")
# Out:
# Extra Trees Regressor
# Mean accuracy score: 0.917, best accuracy score: 0.925, with std dev of: 0.005
# Mean training time: 0.023
# Score on hold out set: 0.919
# Score on time sensitive hold out set: 0.485
# **************
# Lasso Regressor
# Mean accuracy score: 0.853, best accuracy score: 0.869, with std dev of: 0.009
# Mean training time: 0.002
# Score on hold out set: 0.844
# Score on time sensitive hold out set: 0.595
# **************
# Tweedie Regressor
# Mean accuracy score: 0.844, best accuracy score: 0.859, with std dev of: 0.009
# Mean training time: 0.0
# Score on hold out set: 0.843
# Score on time sensitive hold out set: 0.615
# **************
# c:\users\jesse\onedrive\documents\homework\mich\521\ms2_git\lib\site-packages\sklearn\linear_model\_glm\glm.py:294: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
# c:\users\jesse\onedrive\documents\homework\mich\521\ms2_git\lib\site-packages\sklearn\linear_model\_glm\glm.py:294: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
# Dummy Regressor
# Mean accuracy score: -0.029, best accuracy score: -0.021, with std dev of: 0.005
# Mean training time: 0.0
# Score on hold out set: -0.035
# Score on time sensitive hold out set: -0.245
# **************

# %% [markdown]
# ### Examine the feature importances in the best performing model (Extra Trees Regressor)

# %%
feature_importance_df = pd.DataFrame([X.columns, xt_reg.feature_importances_]).transpose()
feature_importance_df.columns = ['Feature', 'Importance']
feature_importance_df.sort_values('Importance',ascending=False,inplace=True)
feature_importance_df.to_csv("small_aa_features.csv",index=False)
feature_importance_df
# Out:
#   Feature Importance
# 0    temp   0.459803
# 1    dwpt   0.393699
# 6    pres    0.04282
# 2    rhum   0.037575
# 4    wdir   0.035001
# 5    wspd   0.023772
# 3    prcp    0.00733

# %%
alt.Chart(feature_importance_df).mark_bar().encode(
    x=alt.X('Importance:Q', axis=alt.Axis(format="%", tickSize=0, labelFontSize=12)),
    y=alt.Y(
        'Feature:N', sort=list(feature_importance_df.Feature), title="",
        axis=alt.Axis(tickSize=0, labelFontSize=12, labelPadding=10)),
).properties(
    height=200
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Hyper-parameter tuning the Extra Trees Regressor
# 5 fold cross validate looking for the optimized estimators, depth, sample split, and sample leaf parameters. Evaluating the 'best' based on the mean squared error achieved.

# %%
space  = [Integer(100,200, name='n_estimators'),
          Integer(1, 50, name='max_depth'),
          Integer(2, 100, name='min_samples_split'),
          Integer(1, 100, name='min_samples_leaf')]

@use_named_args(space)
def objective(**params):
    xt_reg.set_params(**params)

    # return -np.mean(cross_val_score(xt_reg, X_train, y_train, cv=5, n_jobs=-1))
    return -np.mean(value.fit(X[:-1055], y[:-1055]).score(X[-1055:], y[-1055:]))

res_gp = gp_minimize(objective, space, n_calls=18, random_state=696)

print(f"Best score: {res_gp.fun}")
print("Best parameters:")
print(f" - n-estimators= {res_gp.x[0]}")
print(f" - max_depth= {res_gp.x[1]}")
print(f" - min_samples_split= {res_gp.x[2]}")
print(f" - min_samples_leaf=  {res_gp.x[3]}")
# Out:
# Best score: 0.24525736117599162
# Best parameters:
#  - n-estimators= 124
#  - max_depth= 2
#  - min_samples_split= 28
#  - min_samples_leaf=  91

# %% [markdown]
# ### Visualize the convergence for the above hypertuning

# %%
plot_convergence(res_gp)
# Out:
# <AxesSubplot:title={'center':'Convergence plot'}, xlabel='Number of calls $n$', ylabel='$\\min f(x)$ after $n$ calls'>

# %% [markdown]
# ### Final re-run of the Extra Trees Model with the tuned hyperparameters
# There is a very minor improvement on the accuracy score, with some pretty significant increases in training time.

# %%
xt_reg = ExtraTreesRegressor(n_estimators=res_gp.x[0], 
                             max_depth=res_gp.x[1], 
                             min_samples_split=res_gp.x[2], 
                             min_samples_leaf=res_gp.x[3], 
                             random_state=696,n_jobs=-1
                            )
models = {'Extra Trees Regressor':xt_reg}
for key, value in models.items():
    cv_results = cross_validate(value, X_train, y_train, cv=5,n_jobs=-1)
    print(key)
    print("Mean accuracy score: ", end="")
    print(round(cv_results['test_score'].mean(),3), end="")
    print(", best accuracy score: ", end="")
    print(round(cv_results['test_score'].max(),3), end="")
    print(", with std dev of: ", end="")
    print(round(cv_results['test_score'].std(),3))
    print("Mean training time: ", end="")
    print(round(cv_results['score_time'].mean(),3))
    print(f"Score on hold out set: {round(value.fit(X_train, y_train).score(X_test, y_test),3)}")
    print(f"Score on time sensitive hold out set: {round(value.fit(X[:-1055], y[:-1055]).score(X[-1055:], y[-1055:]),3)}")
    print("**************")
# Out:
# Extra Trees Regressor
# Mean accuracy score: 0.771, best accuracy score: 0.777, with std dev of: 0.006
# Mean training time: 0.016
# Score on hold out set: 0.768
# Score on time sensitive hold out set: 0.539
# **************

# %%
final_df = pd.DataFrame()
final_df['Actual'] = y.values
final_df['XT-pred'] = xt_reg.predict(X)
final_df['Lo-pred'] = lasso_reg.predict(X)
final_df['Tw-pred'] = tw_reg.predict(X)
final_df['Dum-pred'] = dummy_reg.predict(X)
final_df['TimeStamp'] = X.index
# final_df = final_df.melt(id_vars='TimeStamp')
final_df.to_csv('small_aaonly_predictions.csv', index=False)

# %% [markdown]
# ## Same general structure/models, now including a longer historical Ann Arbor dataset with some engineered features
# ### Get historical dataset from pickle file

# %%
ROOT_DIR = os.path.realpath(os.path.join(os.getcwd(), '..'))
aa_pkl_loc = os.path.join(ROOT_DIR, 'data','data','aa_historical.pkl')
df = pd.read_pickle(aa_pkl_loc)
df = df[df.index < '2022-10-16']
df.drop(columns=['snow', 'wpgt','tsun','coco','Year'],inplace=True)
df
# Out:
#                      temp  dwpt  rhum  prcp   wdir  wspd    pres  DayOfYear  \
# Timestamp
# 2006-01-01 00:00:00   1.0  -1.1  86.0   NaN  240.0  14.8     NaN        0.0
# 2006-01-01 01:00:00   1.1  -0.1  92.0   0.0  240.0  14.8  1009.0        0.0
# 2006-01-01 02:00:00   0.6   0.0  96.0   NaN  250.0  13.0  1009.5        0.0
# 2006-01-01 03:00:00   1.1  -0.1  92.0   NaN  250.0  13.0  1009.6        0.0
# 2006-01-01 04:00:00   1.1  -0.7  88.0   NaN  250.0  14.8  1010.5        0.0
# ...                   ...   ...   ...   ...    ...   ...     ...        ...
# 2022-10-15 19:00:00  11.1  -0.1  46.0   0.0  210.0  24.1  1013.2      287.0
# 2022-10-15 20:00:00  11.1  -0.1  46.0   0.0  220.0  24.1  1013.7      287.0
# 2022-10-15 21:00:00  10.0  -0.5  48.0   0.0  220.0  20.5  1013.8      287.0
# 2022-10-15 22:00:00   8.0  -1.3  52.0   0.0  220.0   9.0  1014.0      287.0
# 2022-10-15 23:00:00   6.1  -1.1  60.0   0.0  190.0   7.6  1014.3      287.0
#
#                      Hour  HourOfYear  ...  ATAday-wdir  ATAday-wspd  \
# Timestamp                              ...
# 2006-01-01 00:00:00     1         1.0  ...   211.805930    15.509391
# 2006-01-01 01:00:00     2         2.0  ...   211.805930    15.509391
# 2006-01-01 02:00:00     3         3.0  ...   211.805930    15.509391
# 2006-01-01 03:00:00     4         4.0  ...   211.805930    15.509391
# 2006-01-01 04:00:00     5         5.0  ...   211.805930    15.509391
# ...                   ...         ...  ...          ...          ...
# 2022-10-15 19:00:00    20      6908.0  ...   182.588235    12.416010
# 2022-10-15 20:00:00    21      6909.0  ...   182.588235    12.416010
# 2022-10-15 21:00:00    22      6910.0  ...   182.588235    12.416010
# 2022-10-15 22:00:00    23      6911.0  ...   182.588235    12.416010
# 2022-10-15 23:00:00    24      6912.0  ...   182.588235    12.416010
#
#                      ATAday-pres  L5Aday-temp  L5Aday-dwpt  L5Aday-rhum  \
# Timestamp
# 2006-01-01 00:00:00  1016.603158    -3.288983    -5.804237    83.152542
# 2006-01-01 01:00:00  1016.603158    -3.288983    -5.804237    83.152542
# 2006-01-01 02:00:00  1016.603158    -3.288983    -5.804237    83.152542
# 2006-01-01 03:00:00  1016.603158    -3.288983    -5.804237    83.152542
# 2006-01-01 04:00:00  1016.603158    -3.288983    -5.804237    83.152542
# ...                          ...          ...          ...          ...
# 2022-10-15 19:00:00  1014.248379     9.708333     4.791667    74.458333
# 2022-10-15 20:00:00  1014.248379     9.708333     4.791667    74.458333
# 2022-10-15 21:00:00  1014.248379     9.708333     4.791667    74.458333
# 2022-10-15 22:00:00  1014.248379     9.708333     4.791667    74.458333
# 2022-10-15 23:00:00  1014.248379     9.708333     4.791667    74.458333
#
#                      L5Aday-prcp  L5Aday-wdir  L5Aday-wspd  L5Aday-pres
# Timestamp
# 2006-01-01 00:00:00     0.060952   171.171171    12.634188  1017.743860
# 2006-01-01 01:00:00     0.060952   171.171171    12.634188  1017.743860
# 2006-01-01 02:00:00     0.060952   171.171171    12.634188  1017.743860
# 2006-01-01 03:00:00     0.060952   171.171171    12.634188  1017.743860
# 2006-01-01 04:00:00     0.060952   171.171171    12.634188  1017.743860
# ...                          ...          ...          ...          ...
# 2022-10-15 19:00:00     0.182456   167.238095    11.161667  1013.392437
# 2022-10-15 20:00:00     0.182456   167.238095    11.161667  1013.392437
# 2022-10-15 21:00:00     0.182456   167.238095    11.161667  1013.392437
# 2022-10-15 22:00:00     0.182456   167.238095    11.161667  1013.392437
# 2022-10-15 23:00:00     0.182456   167.238095    11.161667  1013.392437
#
# [146685 rows x 38 columns]

# %% [markdown]
# ### Basic cleaning procedures

# %%
cols = ['temp', 'dwpt', 'rhum', 'prcp', 'wdir', 'wspd', 'pres']
for col in cols:
    try:
        df[col].fillna(df[f'ATAhr-{col}'],inplace=True)
    except:
        df[col].fillna(df[f'ATAhr-{col}_x'],inplace=True)
    df[f'24hr~{col}'] = df[col].shift(-24)
df = df[df['24hr~temp'].notna()]

df
# Out:
#                      temp  dwpt  rhum      prcp   wdir  wspd    pres  \
# Timestamp
# 2006-01-01 00:00:00   1.0  -1.1  86.0  0.000000  240.0  14.8  1005.0
# 2006-01-01 01:00:00   1.1  -0.1  92.0  0.000000  240.0  14.8  1009.0
# 2006-01-01 02:00:00   0.6   0.0  96.0  0.235714  250.0  13.0  1009.5
# 2006-01-01 03:00:00   1.1  -0.1  92.0  0.000000  250.0  13.0  1009.6
# 2006-01-01 04:00:00   1.1  -0.7  88.0  0.000000  250.0  14.8  1010.5
# ...                   ...   ...   ...       ...    ...   ...     ...
# 2022-10-14 19:00:00  15.0  -3.4  28.0  0.000000  220.0  19.0  1006.0
# 2022-10-14 20:00:00  13.9  -4.3  28.0  0.000000  220.0  27.7  1006.7
# 2022-10-14 21:00:00  12.8  -5.8  27.0  0.000000  200.0  18.4  1007.3
# 2022-10-14 22:00:00  11.0  -5.1  32.0  0.000000  190.0   9.0  1008.0
# 2022-10-14 23:00:00   8.9  -5.8  35.0  0.000000  120.0   9.4  1008.1
#
#                      DayOfYear  Hour  HourOfYear  ...  L5Aday-wdir  \
# Timestamp                                         ...
# 2006-01-01 00:00:00        0.0     1         1.0  ...   171.171171
# 2006-01-01 01:00:00        0.0     2         2.0  ...   171.171171
# 2006-01-01 02:00:00        0.0     3         3.0  ...   171.171171
# 2006-01-01 03:00:00        0.0     4         4.0  ...   171.171171
# 2006-01-01 04:00:00        0.0     5         5.0  ...   171.171171
# ...                        ...   ...         ...  ...          ...
# 2022-10-14 19:00:00      286.0    20      6884.0  ...   208.207547
# 2022-10-14 20:00:00      286.0    21      6885.0  ...   208.207547
# 2022-10-14 21:00:00      286.0    22      6886.0  ...   208.207547
# 2022-10-14 22:00:00      286.0    23      6887.0  ...   208.207547
# 2022-10-14 23:00:00      286.0    24      6888.0  ...   208.207547
#
#                      L5Aday-wspd  L5Aday-pres  24hr~temp  24hr~dwpt  \
# Timestamp
# 2006-01-01 00:00:00    12.634188  1017.743860        1.1       -1.1
# 2006-01-01 01:00:00    12.634188  1017.743860        1.1       -1.1
# 2006-01-01 02:00:00    12.634188  1017.743860        1.1       -1.1
# 2006-01-01 03:00:00    12.634188  1017.743860        1.1       -0.1
# 2006-01-01 04:00:00    12.634188  1017.743860        1.7       -0.1
# ...                          ...          ...        ...        ...
# 2022-10-14 19:00:00    10.666667  1013.617647       11.1       -0.1
# 2022-10-14 20:00:00    10.666667  1013.617647       11.1       -0.1
# 2022-10-14 21:00:00    10.666667  1013.617647       10.0       -0.5
# 2022-10-14 22:00:00    10.666667  1013.617647        8.0       -1.3
# 2022-10-14 23:00:00    10.666667  1013.617647        6.1       -1.1
#
#                      24hr~rhum  24hr~prcp   24hr~wdir  24hr~wspd  24hr~pres
# Timestamp
# 2006-01-01 00:00:00       85.0   0.000000   80.000000       11.2     1015.4
# 2006-01-01 01:00:00       85.0   0.000000  110.000000        9.4     1015.7
# 2006-01-01 02:00:00       85.0   0.300000  228.666667       11.2     1015.4
# 2006-01-01 03:00:00       92.0   0.800000   80.000000       14.8     1015.1
# 2006-01-01 04:00:00       88.0   0.084615   70.000000       16.6     1014.9
# ...                        ...        ...         ...        ...        ...
# 2022-10-14 19:00:00       46.0   0.000000  210.000000       24.1     1013.2
# 2022-10-14 20:00:00       46.0   0.000000  220.000000       24.1     1013.7
# 2022-10-14 21:00:00       48.0   0.000000  220.000000       20.5     1013.8
# 2022-10-14 22:00:00       52.0   0.000000  220.000000        9.0     1014.0
# 2022-10-14 23:00:00       60.0   0.000000  190.000000        7.6     1014.3
#
# [146661 rows x 45 columns]

# %%
df[df.index > '2022-9']
# Out:
#                      temp  dwpt  rhum  prcp   wdir  wspd    pres  DayOfYear  \
# Timestamp
# 2022-09-01 01:00:00  20.0  12.7  63.0   0.0  280.0  11.2  1013.7      243.0
# 2022-09-01 02:00:00  18.9  12.9  68.0   0.0  280.0  11.2  1014.1      243.0
# 2022-09-01 03:00:00  16.1  12.8  81.0   0.0  270.0   9.4  1014.3      243.0
# 2022-09-01 04:00:00  15.0  12.9  87.0   0.0  260.0   9.4  1014.2      243.0
# 2022-09-01 05:00:00  16.1  13.4  84.0   0.0  250.0  11.2  1014.4      243.0
# ...                   ...   ...   ...   ...    ...   ...     ...        ...
# 2022-10-14 19:00:00  15.0  -3.4  28.0   0.0  220.0  19.0  1006.0      286.0
# 2022-10-14 20:00:00  13.9  -4.3  28.0   0.0  220.0  27.7  1006.7      286.0
# 2022-10-14 21:00:00  12.8  -5.8  27.0   0.0  200.0  18.4  1007.3      286.0
# 2022-10-14 22:00:00  11.0  -5.1  32.0   0.0  190.0   9.0  1008.0      286.0
# 2022-10-14 23:00:00   8.9  -5.8  35.0   0.0  120.0   9.4  1008.1      286.0
#
#                      Hour  HourOfYear  ...  L5Aday-wdir  L5Aday-wspd  \
# Timestamp                              ...
# 2022-09-01 01:00:00     2      5834.0  ...    89.963303     8.250000
# 2022-09-01 02:00:00     3      5835.0  ...    89.963303     8.250000
# 2022-09-01 03:00:00     4      5836.0  ...    89.963303     8.250000
# 2022-09-01 04:00:00     5      5837.0  ...    89.963303     8.250000
# 2022-09-01 05:00:00     6      5838.0  ...    89.963303     8.250000
# ...                   ...         ...  ...          ...          ...
# 2022-10-14 19:00:00    20      6884.0  ...   208.207547    10.666667
# 2022-10-14 20:00:00    21      6885.0  ...   208.207547    10.666667
# 2022-10-14 21:00:00    22      6886.0  ...   208.207547    10.666667
# 2022-10-14 22:00:00    23      6887.0  ...   208.207547    10.666667
# 2022-10-14 23:00:00    24      6888.0  ...   208.207547    10.666667
#
#                      L5Aday-pres  24hr~temp  24hr~dwpt  24hr~rhum  24hr~prcp  \
# Timestamp
# 2022-09-01 01:00:00  1016.401709       18.9       15.6       81.0        0.0
# 2022-09-01 02:00:00  1016.401709       17.2       15.0       87.0        0.0
# 2022-09-01 03:00:00  1016.401709       16.7       15.1       90.0        0.0
# 2022-09-01 04:00:00  1016.401709       14.4       13.3       93.0        0.0
# 2022-09-01 05:00:00  1016.401709       14.4       13.3       93.0        0.0
# ...                          ...        ...        ...        ...        ...
# 2022-10-14 19:00:00  1013.617647       11.1       -0.1       46.0        0.0
# 2022-10-14 20:00:00  1013.617647       11.1       -0.1       46.0        0.0
# 2022-10-14 21:00:00  1013.617647       10.0       -0.5       48.0        0.0
# 2022-10-14 22:00:00  1013.617647        8.0       -1.3       52.0        0.0
# 2022-10-14 23:00:00  1013.617647        6.1       -1.1       60.0        0.0
#
#                      24hr~wdir  24hr~wspd  24hr~pres
# Timestamp
# 2022-09-01 01:00:00      190.0        5.4     1017.2
# 2022-09-01 02:00:00        0.0        0.0     1017.6
# 2022-09-01 03:00:00        0.0        0.0     1018.0
# 2022-09-01 04:00:00        0.0        0.0     1018.1
# 2022-09-01 05:00:00        0.0        0.0     1018.0
# ...                        ...        ...        ...
# 2022-10-14 19:00:00      210.0       24.1     1013.2
# 2022-10-14 20:00:00      220.0       24.1     1013.7
# 2022-10-14 21:00:00      220.0       20.5     1013.8
# 2022-10-14 22:00:00      220.0        9.0     1014.0
# 2022-10-14 23:00:00      190.0        7.6     1014.3
#
# [1055 rows x 45 columns]

# %% [markdown]
# ### Again our target will be the '-24hr~temp_KARB0' column, and our features to use in our first prediction model will be all of the measurements at station "KARB0" 24 hours prior to our target...as well as, the engineered features listed below
#  - All time average for the hour "ATAhr-x" = average for that hour of the year from 2006 to 2022
#  - All time average for the day "ATAday-x" = average for that day of the year from 2006 to 2022
#  - Last 5 year average for the hour "L5Ahr-x" = average for that hour from the last 5 years 2018 to 2022
#  - Last 5 year average for the day "L5Aday-x" = average for that day of the year from the last 5 years 2018 to 2022
#
# This cell will run 5 fold cross-validate on our 3 chosen regression models (Extra Trees Regressor, Lasso Regressor, and Tweedie Regressor). This will show how the average accuracy scores compare across these models on this expanded data set.

# %%
X_cols = [col for col in df.columns if "~" not in col]
X = df[X_cols]
y = df['24hr~temp']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=696)
xt_reg = ExtraTreesRegressor(random_state=696,n_jobs=-1)
lasso_reg = linear_model.Lasso(alpha=0.1,max_iter=1500)
tw_reg = linear_model.TweedieRegressor(max_iter=500)
dummy_reg = DummyRegressor(strategy="median")
models = {'Extra Trees Regressor':xt_reg,
          'Lasso Regressor':lasso_reg,
          'Tweedie Regressor':tw_reg,
          'Dummy Regressor':dummy_reg}
for key, value in models.items():
    cv_results = cross_validate(value, X_train, y_train, cv=5,n_jobs=-1)
    print(key)
    print("Mean accuracy score: ", end="")
    print(round(cv_results['test_score'].mean(),3), end="")
    print(", best accuracy score: ", end="")
    print(round(cv_results['test_score'].max(),3), end="")
    print(", with std dev of: ", end="")
    print(round(cv_results['test_score'].std(),3))
    print("Mean training time: ", end="")
    print(round(cv_results['score_time'].mean(),3))
    print(f"Score on hold out set: {round(value.fit(X_train, y_train).score(X_test, y_test),3)}")
    print(f"Score on time sensitive hold out set: {round(value.fit(X[:-1055], y[:-1055]).score(X[-1055:], y[-1055:]),3)}")
    print("**************")
# Out:
# Extra Trees Regressor
# Mean accuracy score: 0.939, best accuracy score: 0.94, with std dev of: 0.0
# Mean training time: 1.072
# Score on hold out set: 0.944
# Score on time sensitive hold out set: 0.698
# **************
# Lasso Regressor
# Mean accuracy score: 0.871, best accuracy score: 0.871, with std dev of: 0.001
# Mean training time: 0.006
# Score on hold out set: 0.87
# Score on time sensitive hold out set: 0.679
# **************
# Tweedie Regressor
# Mean accuracy score: 0.869, best accuracy score: 0.87, with std dev of: 0.001
# Mean training time: 0.003
# c:\users\jesse\onedrive\documents\homework\mich\521\ms2_git\lib\site-packages\sklearn\linear_model\_glm\glm.py:294: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
# Score on hold out set: 0.868
# c:\users\jesse\onedrive\documents\homework\mich\521\ms2_git\lib\site-packages\sklearn\linear_model\_glm\glm.py:294: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
# Score on time sensitive hold out set: 0.677
# **************
# Dummy Regressor
# Mean accuracy score: -0.001, best accuracy score: -0.0, with std dev of: 0.001
# Mean training time: 0.0
# Score on hold out set: -0.0
# Score on time sensitive hold out set: -0.698
# **************

# %% [markdown]
# ### Examine the feature importances in the best performing model (Extra Trees Regressor)

# %%
feature_importance_df = pd.DataFrame([X.columns, xt_reg.feature_importances_]).transpose()
feature_importance_df.columns = ['Feature', 'Importance']
feature_importance_df.sort_values('Importance',ascending=False,inplace=True)
feature_importance_df.to_csv("full_aa_features.csv",index=False)
feature_importance_df
# Out:
#          Feature Importance
# 10    ATAhr-temp    0.24823
# 0           temp   0.197262
# 17    L5Ahr-temp   0.114201
# 24   ATAday-temp   0.092011
# 31   L5Aday-temp   0.050579
# 11    ATAhr-dwpt   0.037129
# 32   L5Aday-dwpt   0.036246
# 1           dwpt   0.035837
# 25   ATAday-dwpt   0.035037
# 18    L5Ahr-dwpt   0.025853
# 6           pres   0.016472
# 4           wdir   0.015594
# 5           wspd   0.009746
# 12    ATAhr-rhum   0.007931
# 2           rhum   0.007123
# 8           Hour   0.005058
# 19    L5Ahr-rhum   0.004034
# 7      DayOfYear   0.004012
# 28   ATAday-wdir   0.003651
# 35   L5Aday-wdir   0.003592
# 27   ATAday-prcp   0.003539
# 29   ATAday-wspd    0.00342
# 36   L5Aday-wspd   0.003382
# 34   L5Aday-prcp   0.003351
# 30   ATAday-pres   0.003307
# 33   L5Aday-rhum   0.003224
# 37   L5Aday-pres   0.003165
# 26   ATAday-rhum   0.003126
# 23    L5Ahr-pres   0.002877
# 15    ATAhr-wspd   0.002846
# 16    ATAhr-pres   0.002843
# 9     HourOfYear   0.002837
# 3           prcp   0.002732
# 22    L5Ahr-wspd   0.002205
# 21  ATAhr-wdir_y   0.002186
# 14  ATAhr-wdir_x    0.00206
# 13    ATAhr-prcp   0.001747
# 20    L5Ahr-prcp   0.001554

# %%
alt.Chart(feature_importance_df[:5]).mark_bar().encode(
    x=alt.X('Importance:Q', axis=alt.Axis(format="%", tickSize=0, labelFontSize=12)),
    y=alt.Y(
        'Feature:N', sort=list(feature_importance_df[:5].Feature), title="",
        axis=alt.Axis(tickSize=0, labelFontSize=12, labelPadding=10)),
).properties(
    height=200
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Hyper-parameter tuning the Extra Trees Regressor with the expanded dataset
# 5 fold cross validate looking for the optimized estimators, depth, sample split, and sample leaf parameters. Evaluating the 'best' based on the mean squared error achieved.

# %%
space  = [Integer(100,200, name='n_estimators'),
          Integer(1, 50, name='max_depth'),
          Integer(2, 100, name='min_samples_split'),
          Integer(1, 100, name='min_samples_leaf')]

@use_named_args(space)
def objective(**params):
    xt_reg.set_params(**params)

    # return -np.mean(cross_val_score(xt_reg, X_train, y_train, cv=5, n_jobs=-1))
    return -np.mean(value.fit(X[:-1055], y[:-1055]).score(X[-1055:], y[-1055:]))

res_gp = gp_minimize(objective, space, n_calls=15, random_state=696)

print(f"Best score: {res_gp.fun}")
print("Best parameters:")
print(f" - n-estimators= {res_gp.x[0]}")
print(f" - max_depth= {res_gp.x[1]}")
print(f" - min_samples_split= {res_gp.x[2]}")
print(f" - min_samples_leaf=  {res_gp.x[3]}")
# Out:
# Best score: 0.6980146916602039
# Best parameters:
#  - n-estimators= 124
#  - max_depth= 2
#  - min_samples_split= 28
#  - min_samples_leaf=  91

# %% [markdown]
# ### Plot the convergence of the hyperparameter tuning

# %%
plot_convergence(res_gp)
# Out:
# <AxesSubplot:title={'center':'Convergence plot'}, xlabel='Number of calls $n$', ylabel='$\\min f(x)$ after $n$ calls'>

# %% [markdown]
# ### Re-train the model with the tuned hyper-parameters
# Again, only marginal accuracy improvements achieved with the tuned parameters

# %%
xt_reg = ExtraTreesRegressor(n_estimators=res_gp.x[0], 
                             max_depth=res_gp.x[1], 
                             min_samples_split=res_gp.x[2], 
                             min_samples_leaf=res_gp.x[3], 
                             random_state=696,n_jobs=-1
                            )
models = {'Extra Trees Regressor':xt_reg}
for key, value in models.items():
    cv_results = cross_validate(value, X_train, y_train, cv=5,n_jobs=-1)
    print(key)
    print("Mean accuracy score: ", end="")
    print(round(cv_results['test_score'].mean(),3), end="")
    print(", best accuracy score: ", end="")
    print(round(cv_results['test_score'].max(),3), end="")
    print(", with std dev of: ", end="")
    print(round(cv_results['test_score'].std(),3))
    print("Mean training time: ", end="")
    print(round(cv_results['score_time'].mean(),3))
    print(f"Score on hold out set: {round(value.fit(X_train, y_train).score(X_test, y_test),3)}")
    print(f"Score on time sensitive hold out set: {round(value.fit(X[:-1055], y[:-1055]).score(X[-1055:], y[-1055:]),3)}")
    print("**************")
# Out:
# Extra Trees Regressor
# Mean accuracy score: 0.789, best accuracy score: 0.79, with std dev of: 0.001
# Mean training time: 1.009
# Score on hold out set: 0.787
# Score on time sensitive hold out set: 0.545
# **************

# %%
final_df = pd.DataFrame()
final_df['Actual'] = y.values
final_df['XT-pred'] = xt_reg.predict(X)
final_df['Lo-pred'] = lasso_reg.predict(X)
final_df['Tw-pred'] = tw_reg.predict(X)
final_df['Dum-pred'] = dummy_reg.predict(X)
final_df['TimeStamp'] = X.index
# final_df = final_df.melt(id_vars='TimeStamp')
final_df.to_csv('full_aaonly_predictions.csv', index=False)

# %% [markdown]
# # UNFINISHED WORK

# %%
pred_df = pd.DataFrame()
pred_df['Actual'] = y.values
pred_df['XT-pred'] = xt_reg.predict(X)
pred_df['Lo-pred'] = lasso_reg.predict(X)
pred_df['Tw-pred'] = tw_reg.predict(X)
# pred_df['Dum-pred'] = dummy_reg.predict(X)
pred_df['TimeStamp'] = df.index
pred_df = pred_df.melt(id_vars='TimeStamp')
pred_df = pred_df[pred_df['TimeStamp']>'2022-09']
# pred_df = pred_df[pred_df['TimeStamp'].dt.month == 10]

# %%
alt.data_transformers.disable_max_rows()
alt.Chart(pred_df).mark_line().encode(
    x=alt.X('TimeStamp:T', axis=alt.Axis(tickSize=0, labelFontSize=12)),
    y=alt.Y('value:Q'),
    color='variable',
    strokeDash='variable',
    row=alt.Row('variable:N')
).properties(
    height=100,
    width=600
)
# Out:
# alt.Chart(...)

# %%
alt.data_transformers.disable_max_rows()
alt.Chart(pred_df).mark_line().encode(
    x=alt.X('TimeStamp:T', axis=alt.Axis(tickSize=0, labelFontSize=12)),
    y=alt.Y('value:Q'),
    color='variable',
    strokeDash='variable'
).properties(
    height=300,
    width=800
)
# Out:
# alt.Chart(...)
