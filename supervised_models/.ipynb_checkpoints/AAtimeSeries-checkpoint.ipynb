# %%
import os
import pandas as pd
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %%
ROOT_DIR = os.path.realpath(os.path.join(os.getcwd(), '..'))
cln_pkl_loc = os.path.join(ROOT_DIR, 'data','AAcleaned.pkl')

# %%
df=pd.read_pickle(cln_pkl_loc)
df
df.reset_index(inplace=True)
# Out:
#                      temp  dwpt  rhum          prcp   wdir  wspd    pres
# time
# 2006-01-01 01:00:00   1.1  -0.1  92.0  0.000000e+00  240.0  14.8  1009.0
# 2006-01-01 02:00:00   0.6   0.0  96.0  1.510499e-07  250.0  13.0  1009.5
# 2006-01-01 03:00:00   1.1  -0.1  92.0  1.000469e-07  250.0  13.0  1009.6
# 2006-01-01 04:00:00   1.1  -0.7  88.0  2.972019e-08  250.0  14.8  1010.5
# 2006-01-01 05:00:00   1.1  -0.1  92.0  0.000000e+00  240.0  16.6  1010.9
# ...                   ...   ...   ...           ...    ...   ...     ...
# 2022-09-22 18:00:00  16.0   4.4  46.0  0.000000e+00  340.0  20.0  1017.0
# 2022-09-22 19:00:00  15.0   3.5  46.0  0.000000e+00  320.0  25.9  1017.6
# 2022-09-22 20:00:00  16.1   4.5  46.0  0.000000e+00  320.0  18.4  1017.9
# 2022-09-22 21:00:00  16.0   4.4  46.0  0.000000e+00  330.0  22.0  1019.0
# 2022-09-22 22:00:00  14.0   2.9  47.0  0.000000e+00  330.0  22.0  1019.0
#
# [146614 rows x 7 columns]

# %%
dfgraph=df[(df['time']>='2014-09-01') & (df['time']<='2014-10-01')]
x= dfgraph['time']
y= dfgraph['temp']

figure(figsize=(20,6))
plt.scatter(x,y)
plt.show()
