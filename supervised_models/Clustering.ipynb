# %% [markdown]
# ### Clustering to reduce features

# %%
import os
import pandas as pd
from datetime import datetime, timedelta
from sklearn.neighbors import KNeighborsClassifier
from sklearn.cluster import KMeans
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler

# %%
ROOT_DIR = os.path.realpath(os.path.join(os.getcwd(), '..'))
cln_pkl_loc = os.path.join(ROOT_DIR, 'data','cleanweathersmall.pkl')

# %%
df = pd.read_pickle(cln_pkl_loc)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3657000 entries, 0 to 3656999
# Data columns (total 9 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   station  object
#  1   time     datetime64[ns]
#  2   temp     float64
#  3   dwpt     float64
#  4   rhum     float64
#  5   prcp     float64
#  6   wdir     float64
#  7   wspd     float64
#  8   pres     float64
# dtypes: datetime64[ns](1), float64(7), object(1)
# memory usage: 279.0+ MB

# %% [markdown]
# ### 1. shifting time by 24 hours for Ann Arbor

# %%
df_AA=df[df['station']=="KARB0"] #spliting off AA so I don't adjust its time.

# %%
df_AA
# Out:
#         station                time  temp  dwpt  rhum  prcp   wdir  wspd  \
# 1310160   KARB0 2022-01-01 00:00:00   5.0   2.9  86.0   0.0  120.0  15.0
# 1310161   KARB0 2022-01-01 01:00:00   5.0   2.9  86.0   0.0  120.0  11.2
# 1310162   KARB0 2022-01-01 02:00:00   5.0   2.9  86.0   0.0  120.0   5.4
# 1310163   KARB0 2022-01-01 03:00:00   5.0   2.9  86.0   0.0    0.0   0.0
# 1310164   KARB0 2022-01-01 04:00:00   5.6   3.3  85.0   0.0    0.0   0.0
# ...         ...                 ...   ...   ...   ...   ...    ...   ...
# 1316515   KARB0 2022-09-22 19:00:00  16.1   2.8  41.0   0.0  329.0  26.6
# 1316516   KARB0 2022-09-22 20:00:00  16.1   2.8  41.0   0.0  328.0  26.3
# 1316517   KARB0 2022-09-22 21:00:00  15.8   2.6  41.0   0.0  329.0  25.2
# 1316518   KARB0 2022-09-22 22:00:00  15.7   2.1  40.0   0.0  332.0  24.8
# 1316519   KARB0 2022-09-22 23:00:00  14.8   2.3  43.0   0.0  334.0  19.8
#
#            pres
# 1310160  1005.0
# 1310161  1005.4
# 1310162  1005.3
# 1310163  1004.9
# 1310164  1004.9
# ...         ...
# 1316515  1017.0
# 1316516  1017.2
# 1316517  1017.4
# 1316518  1017.8
# 1316519  1018.3
#
# [6360 rows x 9 columns]

# %%
df_NOAA=df[df['station']!="KARB0"]

# %%
df_NOAA['time']=df_NOAA['time']+timedelta(hours=24) #adds 24
# Out:
# C:\Users\paull\AppData\Local\Temp\ipykernel_71516\4277429291.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_NOAA['time']=df_NOAA['time']+timedelta(hours=24) #adds 24

# %%
df_AA
# Out:
#         station                time  temp  dwpt  rhum  prcp   wdir  wspd  \
# 1310160   KARB0 2022-01-01 00:00:00   5.0   2.9  86.0   0.0  120.0  15.0
# 1310161   KARB0 2022-01-01 01:00:00   5.0   2.9  86.0   0.0  120.0  11.2
# 1310162   KARB0 2022-01-01 02:00:00   5.0   2.9  86.0   0.0  120.0   5.4
# 1310163   KARB0 2022-01-01 03:00:00   5.0   2.9  86.0   0.0    0.0   0.0
# 1310164   KARB0 2022-01-01 04:00:00   5.6   3.3  85.0   0.0    0.0   0.0
# ...         ...                 ...   ...   ...   ...   ...    ...   ...
# 1316515   KARB0 2022-09-22 19:00:00  16.1   2.8  41.0   0.0  329.0  26.6
# 1316516   KARB0 2022-09-22 20:00:00  16.1   2.8  41.0   0.0  328.0  26.3
# 1316517   KARB0 2022-09-22 21:00:00  15.8   2.6  41.0   0.0  329.0  25.2
# 1316518   KARB0 2022-09-22 22:00:00  15.7   2.1  40.0   0.0  332.0  24.8
# 1316519   KARB0 2022-09-22 23:00:00  14.8   2.3  43.0   0.0  334.0  19.8
#
#            pres
# 1310160  1005.0
# 1310161  1005.4
# 1310162  1005.3
# 1310163  1004.9
# 1310164  1004.9
# ...         ...
# 1316515  1017.0
# 1316516  1017.2
# 1316517  1017.4
# 1316518  1017.8
# 1316519  1018.3
#
# [6360 rows x 9 columns]

# %%
#removing first day and last day 
#(manual current but could be automated)
df_AA24HR=pd.concat([df_AA,df_NOAA])
df_AA24HR=df_AA24HR[(df_AA24HR['time']>='2022-01-02 00:00:00') & (df_AA24HR['time']<='2022-09-22 23:00:00')]

# %% [markdown]
# ### 2. Clustering

# %%
#Scaling all values for kmeans - normalizing columns

scaler = StandardScaler() #read that standard scaler is probably best for knn vs min/max (first attempt)
scaler.fit(df_AA24HR.iloc[:,2:9])
scaled=scaler.fit_transform(df_AA24HR.iloc[:,2:9])
scaled_df=pd.DataFrame(scaled, columns = df.iloc[:2,2:9].columns)
#normalized = preprocessing.normalize(df_AA24HR.iloc[:,2:9])
#normalized
#testknn=df_AA24HR[df_AA24HR['time']=='2022-01-02 1:00:00']
scaled_df=df_AA24HR.iloc[:,0:2].merge(scaled_df, left_index=True, right_index=True)
scaled_df.head()

#testing
scaled_df=scaled_df[scaled_df['time']<='2022-03-30 00:00:00']

# %%
#creating a results DF
result_df=pd.DataFrame(scaled_df.station.unique(), columns=['station'])
result_df['total']=0
result_df
# Out:
#     station  total
# 0     KARB0      0
# 1     0CNUO      0
# 2     0CO7B      0
# 3     0FV1F      0
# 4     1J1PJ      0
# ..      ...    ...
# 568   UJHR7      0
# 569   UV7W2      0
# 570   V5792      0
# 571   VMWBN      0
# 572   XM44W      0
#
# [573 rows x 2 columns]

# %%
#the actual kmeans
knn = KMeans(n_clusters=15) #need to tune this value and try other clustering (hierarchical) to find stable values
for t in scaled_df.time.unique(): #looping through every hour
    dfhour=scaled_df[scaled_df['time']==t].copy()
    knndata=dfhour.iloc[:,2:9]
    knn.fit(knndata)
    y_kmeans = knn.predict(knndata)
    dfhour['cluster']=y_kmeans #finding clusters
    AAcluster=dfhour.loc[dfhour.station=='KARB0','cluster'].values[0] #finding cluster AA is in
    df_resulthr=dfhour[dfhour['cluster']==AAcluster].copy()
    df_resulthr['total']=1 #setting a threshold
    result_df=pd.concat([result_df, df_resulthr[['station','total']]]).groupby(['station']).sum().reset_index() #joining back to my results df.  I wasn't sure how else to do this.  
result_df
# Out:
#     station  total
# 0     0CNUO     51
# 1     0CO7B    103
# 2     0FV1F     86
# 3     1J1PJ    108
# 4     1JWST     83
# ..      ...    ...
# 568   UJHR7     62
# 569   UV7W2     69
# 570   V5792     59
# 571   VMWBN     51
# 572   XM44W     38
#
# [573 rows x 2 columns]

# %%
station_loc = os.path.join(ROOT_DIR, 'station_analysis','AAstation.csv') #station data to get distance for comparision
dfstations=pd.read_csv(station_loc)
    #result_df.sort_values(by='total',ascending=False).head(60)
pd.merge(result_df,dfstations,left_on='station', right_on='id').sort_values(by='total',ascending=False).head(21) #top 20 locations (top will be AA)
# Out:
#     station  total     id                                        name country  \
# 206   KARB0   2089  KARB0                      Ann Arbor / Pittsfield      US
# 208   KARV0    639  KARV0                         Minocqua / Woodruff      US
# 209   KASW0    493  KASW0                           Warsaw / Monoquet      US
# 207   KARR0    464  KARR0                        Aurora / Sugar Grove      US
# 472   KPNT0    456  KPNT0                            Pontiac / Cayuga      US
# 471   KPNM0    446  KPNM0        Princeton / Princetown [Misspelling]      US
# 465   KPHN0    440  KPHN0                     Port Huron / Marysville      US
# 200   KAMN0    430  KAMN0                               Alma / Eugene      US
# 475   KPQN0    425  KPQN0                                   Pipestone      US
# 484   KRDK0    424  KRDK0    Red Oak / Villa Village Mobile Home Park      US
# 473   KPOV0    423  KPOV0                   Ravenna / Birchwood Manor      US
# 195   KAHQ0    422  KAHQ0                                       Wahoo      US
# 470   KPMV0    420  KPMV0                        Plattsmouth / Mynard      US
# 464   KPHD0    420  KPHD0      New Philadelphia / Schoenbrunn Estates      US
# 196   KAIG0    418  KAIG0                                      Antigo      US
# 188   KACQ0    416  KACQ0   Waseca / Vista-Villa Mobilehome Community      US
# 461   KPDC0    406  KPDC0  Prairie Du Chien / Selchs Mobile Home Park      US
# 202   KANQ0    403  KANQ0                              Angola / Flint      US
# 205   KAQP0    402  KAQP0                                    Appleton      US
# 463   KPEX0    397  KPEX0                                 Paynesville      US
# 198   KAIT0    389  KAIT0  Aitkin / Welshons Company Mobile Home Park      US
#
#     region  wmo  icao  latitude  longitude  elevation  \
# 206     MI  NaN  KARB   42.2230   -83.7456      256.0
# 208     WI  NaN  KARV   45.9279   -89.7309      497.0
# 209     IN  NaN  KASW   41.2747   -85.8401      259.0
# 207     IL  NaN  KARR   41.7719   -88.4757      217.0
# 472     IL  NaN  KPNT   40.9244   -88.6239      203.0
# 471     MN  NaN  KPNM   45.5599   -93.6082      299.0
# 465     MI  NaN  KPHN   42.9110   -82.5289      198.0
# 200     MI  NaN  KAMN   43.3221   -84.6879      230.0
# 475     MN  NaN  KPQN   43.9833   -96.3003      529.0
# 484     IA  NaN  KRDK   41.0108   -95.2589      319.0
# 473     OH  NaN  KPOV   41.2102   -81.2516      365.0
# 195     NE  NaN  KAHQ   41.2406   -96.5946      373.0
# 470     NE  NaN  KPMV   40.9484   -95.9174      367.0
# 464     OH  NaN  KPHD   40.4702   -81.4199      273.0
# 196     WI  NaN  KAIG   45.1542   -89.1107      464.0
# 188     MN  NaN  KACQ   44.0735   -93.5529      344.0
# 461     WI  NaN  KPDC   43.0193   -91.1237      201.0
# 202     IN  NaN  KANQ   41.6397   -85.0835      303.0
