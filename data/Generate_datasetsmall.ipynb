# %%
from datetime import datetime
from meteostat import Stations, Hourly
import pickle

# %%
stations = Stations()
stations = stations.bounds((50, -100), (40, -80))
stationlist=stations.fetch()
#print('Stations in northern hemisphere:', stations.count())
stationlist
# Out:
#                                     name country region    wmo  icao  \
# id
# 0CNUO                        Rawson Lake      CA     ON   <NA>  <NA>
# 0CO7B                     Kingsville Moe      CA     ON   <NA>  <NA>
# 0FV1F                   Tillsonburg Wwtp      CA     ON   <NA>  <NA>
# 13178                          Jamestown      CA     ON   <NA>  <NA>
# 1J1PJ                           Gore Bay      CA     ON  71956  <NA>
# ...                                  ...     ...    ...    ...   ...
# ZFZUV              Winnipeg Intl Airport      CA     MB   <NA>  <NA>
# ZNWZW         Columbus Municipal Airport      US     NE   <NA>  KOLU
# ZUQJS          Ephraim-Gibraltar Airport      US     WI   <NA>  K3D2
# ZWC6W                Kapuskasing Airport      CA     ON   <NA>  <NA>
# ZYITU  Selfridge Air National Guard Base      US     MI   <NA>  KMTC
#
#        latitude  longitude  elevation             timezone hourly_start  \
# id
# ...

# %%
start = datetime(2021, 1, 1)
end = datetime(2022, 10, 15, 23, 59)

# %%
len(stationlist)#print(stationlist)
# Out:
# 632

# %%
Hourly.cache_dir = r'data/cache'
data = Hourly(stationlist, start=start, end=end)
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# Input In [33], in <cell line: 2>()
#       1 Hourly.cache_dir = r'data/cache'
# ----> 2 data = Hourly(stationlist, start=start, end=end)
#
# File ~\Anaconda32\lib\site-packages\meteostat\interface\hourly.py:153, in Hourly.__init__(self, loc, start, end, timezone, model, flags)
#     150 self._set_time(start, end, timezone)
#     152 # Initialize time series
# --> 153 self._init_time_series(loc, start, end, model, flags)
#
# File ~\Anaconda32\lib\site-packages\meteostat\interface\timeseries.py:170, in TimeSeries._init_time_series(self, loc, start, end, model, flags)
#     167 self._flags = flags
#     169 # Get data for all weather stations
# --> 170 self._data = self._get_data()
#     172 # Load source flags through map file
#     173 # if flags are explicitly requested or
#     174 # model data is excluded
# ...

# %%
#data = Hourly('72219', start, end)
data = data.fetch()

# %%
data

# %%
data

# %%
len(data.index.unique(level=0))
# Out:
# 607

# %%
print(data)
# Out:
#                              temp  dwpt  rhum  prcp  snow   wdir  wspd  wpgt  \
# station time
# 0CNUO   2022-01-01 00:00:00 -25.1 -28.1  76.0   0.0   NaN  271.0  12.6   NaN
#         2022-01-01 01:00:00 -25.7 -28.7  76.0   0.0   NaN  275.0  13.0   NaN
#         2022-01-01 02:00:00 -26.2 -29.3  75.0   0.0   NaN  273.0  12.6   NaN
#         2022-01-01 03:00:00 -26.1 -29.1  76.0   0.0   NaN  277.0  13.7   NaN
#         2022-01-01 04:00:00 -26.5 -29.6  75.0   0.0   NaN  275.0  13.3   NaN
# ...                           ...   ...   ...   ...   ...    ...   ...   ...
# ZYITU   2022-09-22 19:00:00  15.3   4.6  49.0   0.0   NaN  330.0  37.1   NaN
#         2022-09-22 20:00:00  16.0   3.4  43.0   0.0   NaN  340.0  33.0   NaN
#         2022-09-22 21:00:00  14.3   4.0  50.0   0.0   NaN  330.0  22.3   NaN
#         2022-09-22 22:00:00  14.2   3.3  48.0   0.0   NaN  320.0  24.1   NaN
#         2022-09-22 23:00:00  13.0   3.9  54.0   0.0   NaN  330.0  15.0   NaN
#
# ...

# %%
data.to_pickle(r'data/weathersmallraw.pkl')
