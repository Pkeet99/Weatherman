# %%
import pandas as pd
from meteostat import Stations
import os

# %%
stations = Stations()
stations = stations.bounds((50, -110), (30, -65))
stationlist=stations.fetch()

# %%
stationlist.groupby(['country','region']).count()
# Out:
#                 name  wmo  icao  latitude  longitude  elevation  timezone  \
# country region
# CA      AB         3    0     3         3          3          3         3
#         BC         1    0     1         1          1          1         1
#         MB        36   18    14        36         36         36        36
#         NB        32   19    18        32         32         32        32
#         NS        10    6     5        10         10         10        10
#         ON       218   98    99       218        218        218       218
#         QC       225   82    85       225        225        225       225
#         SK        20   12    10        20         20         20        20
# MX      CHH        2    1     2         2          2          2         2
#         SON        1    1     0         1          1          1         1
# US      AK         1    0     1         1          1          1         1
# ...

# %%
if not os.path.isdir(r'data/cache'):
    os.makedirs(r'data/cache')

# %%
from datetime import datetime
from meteostat import Hourly

Hourly.cache_dir = r'data/cache'

# Set time period
start = datetime(2019, 1, 1)
end = datetime(2022, 10, 16, 23, 59)

# Get hourly data
data = Hourly(stationlist, start, end)
data = data.fetch()
data
# Out:
# ...
# ...
# ...
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# Cell In [6], line 11
#       8 end = datetime(2022, 10, 16, 23, 59)
#      10 # Get hourly data
# ---> 11 data = Hourly(stationlist, start, end)
#      12 data = data.fetch()
#      13 data
#
# File c:\users\jesse\onedrive\documents\homework\mich\521\ms2_git\lib\site-packages\meteostat\interface\hourly.py:153, in Hourly.__init__(self, loc, start, end, timezone, model, flags)
#     150 self._set_time(start, end, timezone)
#     152 # Initialize time series
# --> 153 self._init_time_series(loc, start, end, model, flags)
#
# File c:\users\jesse\onedrive\documents\homework\mich\521\ms2_git\lib\site-packages\meteostat\interface\timeseries.py:170, in TimeSeries._init_time_series(self, loc, start, end, model, flags)
#     167 self._flags = flags
#     169 # Get data for all weather stations
# --> 170 self._data = self._get_data()
# ...

# %%
data.to_pickle('data/weatherraw.pkl')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [7], line 1
# ----> 1 data.to_pickle('data/weatherraw.pkl')
#
# NameError: name 'data' is not defined
